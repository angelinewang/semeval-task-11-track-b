# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\agupt\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\agupt\anaconda3\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\agupt\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\agupt\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\agupt\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: fsspec in c:\users\agupt\anaconda3\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\agupt\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\agupt\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\agupt\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\agupt\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\agupt\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\agupt\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\agupt\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\agupt\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\agupt\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import recall_score, precision_score, f1_score

import torch 
from torch import nn
from torch import optim

import datetime

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import ngrams
from nltk import word_tokenize, pos_tag
from sklearn import metrics
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys

# %%
import nltk

nltk.download("wordnet")
nltk.download("punkt")
nltk.download('omw-1.4')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\agupt\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\agupt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\agupt\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\agupt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load the training and validation data

train = pd.read_csv('../public_data/train/track_a/eng.csv')
val = pd.read_csv('../public_data/dev/track_a/eng_a.csv')

train.head()
# Out:
#                         id                                               text  \
# 0  eng_train_track_a_00001                                But not very happy.
# 1  eng_train_track_a_00002  Well she's not gon na last the whole song like...
# 2  eng_train_track_a_00003  She sat at her Papa's recliner sofa only to mo...
# 3  eng_train_track_a_00004                    Yes, the Oklahoma city bombing.
# 4  eng_train_track_a_00005                       They were dancing to Bolero.
#
#    Anger  Fear  Joy  Sadness  Surprise
# 0      0     0    1        1         0
# 1      0     0    1        0         0
# 2      0     0    0        0         0
# 3      1     1    0        1         1
# 4      0     0    1        0         0

# %%
## Add Tokeniser search
from transformers import BertTokenizer

# Load pre-trained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# POS Tagging
import spacy
nlp = spacy.load("en_core_web_sm")

# SPACY TOKENISER SETUP 
# import spacy
# nlp = spacy.load("en_core_web_sm")

# NLTK TREEBANK TOKENISER SETUP
# from nltk.tokenize import TreebankWordTokenizer

# NLTK WORDPUNCT TOKENISER SETUP 
# from nltk.tokenize import WordPunctTokenizer


# Tokenize and encode the text

def pre_process(text, config):
    """ 
    Performs Different preprocessing operations.

    Parameters:
    text (string): passes a line of text (assume sentence segmentation has already been done)

    Returns:
    List[string]: Should return a list of tokens.
    """

    def separate_punctuation(text):
        text = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", text)
        text = re.sub(r"([.,;:!?'\"“\(\)])(\w)", r"\1 \2", text)
        return text

    def remove_punctuation(text):
        text = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1", text)
        text = re.sub(r"([.,;:!?'\"“\(\)])(\w)", r"\2", text)
        return text
        
    def tokenize_text(text):
        # Original tokeniser:
        # tokens = re.split(r"\s+",text)
        # tokens = [t.lower() for t in tokens]
        
        # BERT TOKENISER SETUP
        # Encode text returns a BatchEncoding object
        encoded_input = tokenizer(text, return_tensors='pt', add_special_tokens=True)
        # Convert token ids to words
        tokens = tokenizer.convert_ids_to_tokens(encoded_input['input_ids'][0])
        return tokens

        # SPACY TOKENISER SETUP
        # doc = nlp(text)
        # # Collect only the text of each token in the document
        # tokens = [token.text for token in doc]

        # NLTK TREEBANKWORD TOKENIZER 
        # tokenizer = TreebankWordTokenizer()
        # tokens = tokenizer.tokenize(text)

        # NLTK WORDPUNCT TOKENIZER
        # tokenizer = WordPunctTokenizer()
        # tokens = tokenizer.tokenize(text)

        # Return the list of tokens
        # return tokens

    def apply_stemming(tokens):
        stemmer = PorterStemmer()
        stemmed_tokens = [stemmer.stem(token) for token in tokens]
        return stemmed_tokens

    def apply_lemmatization(tokens):
        lemmatizer = WordNetLemmatizer()
        lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
        return lemmatized_tokens

    def generate_ngrams_from_tokens(tokens, n):
        return list(ngrams(tokens, n))

    # Separate Punctuation otherwise Remove it
    
    if config["sep_pn"] and not config["rm_pn"]:
        text = separate_punctuation(text)

    if config["rm_pn"] and not config["sep_pn"]:
        text = remove_punctuation(text)
    
    # tokenize text
    
    tokens = tokenize_text(text)

    # POS Tagging
    # Reconstruct the full text from subwords, handling special tokens
    reconstructed_text = tokenizer.convert_tokens_to_string(tokens)
    # Process the reconstructed text with spaCy
    doc = nlp(reconstructed_text)

    # POS tagging
    for token in doc:
        print(token.text, token.pos_)

    # Apply Lemmatization or Stemming

    if config["apply_stemming"]:
        tokens = apply_stemming(tokens)
    if config["apply_lemmatization"]:
        tokens = apply_lemmatization(tokens)

    # Generate bigrams, trigrams and quadgrams
    if config["add_bigrams"]:
        bigrams = generate_ngrams_from_tokens(tokens, 2)
        bg = [i + " " + j for (i,j) in bigrams]
        tokens += bg

    # Remove Stop words
    
    if config["rm_sw"]:
        stop_words = set(stopwords.words('english'))
        tokens = [w for w in tokens if w not in stop_words]

    # stop_words = set(stopwords.words('english'))
    # tokens = [w for w in tokens if w not in stop_words]

    return " ".join(tokens)

# %%
# import itertools

# def grid_configurations():
#     options = [
#         "sep_pn", "rm_pn", "apply_lemmatization", "apply_stemming", "add_bigrams", "rm_sw"
#     ]
    
#     # Generate all combinations of True/False for each option
#     combinations = itertools.product([True, False], repeat=len(options))
    
#     configurations = []
    
#     # Create a dictionary for each combination
#     for combo in combinations:
#         config = {options[i]: combo[i] for i in range(len(options))}
#         configurations.append(config)
    
#     return configurations

# # Example usage
# results = []
# configs = grid_configurations()
# for _i, config in enumerate(configs):
#     vectorizer = CountVectorizer()
#     X_train = vectorizer.fit_transform([pre_process(i, config) for i in train["text"]]).toarray()
#     X_val = vectorizer.transform(val['text'].str.lower()).toarray()

#     emotions = ['Joy','Sadness','Surprise','Fear','Anger']
#     y_train = train[emotions].values
#     y_val = val[emotions].values

#     X_train_t = torch.Tensor(X_train)
#     y_train_t = torch.Tensor(y_train)

#     X_val_t = torch.Tensor(X_val)
#     y_val_t = torch.Tensor(y_val)

#     model = nn.Sequential(
#           nn.Linear(X_train.shape[1], 100),
#           nn.ReLU(),
#           nn.Dropout(0.3),
#           nn.Linear(100, y_train.shape[1])
#         )
    
#     criterion = nn.BCEWithLogitsLoss()
#     optimizer = optim.SGD(model.parameters(), lr=1e-1, weight_decay=1e-2)
#     loss = None
#     # Train for a set number of epochs
#     for epoch in range(200):
#         optimizer.zero_grad()
#         output = model(X_train_t)
#         loss = criterion(output, y_train_t)
#         loss.backward()
#         optimizer.step()
#     results.append((round(loss.item(),3), _i))
#     print(_i, round(loss.item(),3), config)
# print("MIN LOSS: ", min(results))

# %%
# [(i, pre_process(i, {'sep_pn': True, 'rm_pn': False, 'apply_lemmatization': True, 'apply_stemming': True, 'add_bigrams': True, 'rm_sw': False})) for i in train["text"]]

# %%
# ## Add Tokeniser search
# from transformers import BertTokenizer

# # Load pre-trained BERT tokenizer
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# # Tokenize and encode the text

# tokens = tokenizer("Example text for sentiment analysis", return_tensors="pt")

# `inputs` now contains input IDs and attention masks that can be fed into a BERT model

# %%
# import spacy
# nlp = spacy.load("en_core_web_sm")
# doc = nlp("Your sample text goes here.")
# tokens = [token.text for token in doc]

# from nltk.tokenize import TweetTokenizer
# tokenizer = TweetTokenizer()
# tokens = tokenizer.tokenize("Your sample tweet goes here :) #exciting")

# %%
vectorizer = CountVectorizer()

# Use TF-IDF Vectoriser instead

# from sklearn.feature_extraction.text import TfidfVectorizer

# Create a TfidfVectorizer object
# vectorizer = TfidfVectorizer()

val_features = [pre_process(i, config) for i in val["text"]]

# Optimal config #18 
config = {'sep_pn': True, 'rm_pn': False, 'apply_lemmatization': True, 'apply_stemming': True, 'add_bigrams': True, 'rm_sw': False}

val_features = [pre_process(i, config) for i in val["text"]]

X_train = vectorizer.fit_transform([pre_process(i, config) for i in train["text"]]).toarray()
X_val = vectorizer.transform(val_features).toarray()

emotions = ['Joy','Sadness','Surprise','Fear','Anger']
y_train = train[emotions].values
y_val = val[emotions].values

print(X_val.shape)
print(X_train.shape)
# Out:
# [ X
# CLS X
# ] X
# my PRON
# mouth NOUN
# fell VERB
# open ADJ
# ` PUNCT
# ` PUNCT
# no INTJ
# , PUNCT
# no INTJ
# , PUNCT
# no INTJ
# . PUNCT
# . PUNCT
# . PUNCT
# i PRON
# . PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# you PRON
# can AUX
# barely ADV
# make VERB
# out ADP
# your PRON
# daughter NOUN
# ' PUNCT
# s PART
# pale ADJ
# form NOUN
# in ADP
# the DET
# darkness NOUN
# of ADP
# your PRON
# room NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# but CCONJ
# after ADP
# blinking VERB
# my PRON
# eyes NOUN
# for ADP
# a DET
# few ADJ
# times NOUN
# lepas VERB
# tu PROPN
# tampar NOUN
# - PUNCT
# tampar NOUN
# muka PROPN
# sikit PROPN
# , PUNCT
# memang PROPN
# sah PROPN
# la PROPN
# yang PROPN
# penghantar PROPN
# itu PROPN
# hanis PROPN
# zalikha PROPN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# slowly ADV
# rising VERB
# to ADP
# my PRON
# feet NOUN
# i PRON
# came VERB
# to ADP
# the DET
# conclusion NOUN
# that SCONJ
# sometimes ADV
# being AUX
# alone ADV
# meant VERB
# surviving VERB
# for ADP
# myself PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# noticed VERB
# this DET
# months NOUN
# after ADP
# moving VERB
# in ADV
# and CCONJ
# doing VERB
# all PRON
# of ADP
# my PRON
# basic ADJ
# routines NOUN
# in ADP
# my PRON
# room NOUN
# naked ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# know VERB
# not PART
# why SCONJ
# , PUNCT
# i PRON
# wipe VERB
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# was AUX
# rather ADV
# insulting ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# born VERB
# without ADP
# the DET
# compassion NOUN
# chromosome NOUN
# , PUNCT
# or CCONJ
# i PRON
# could AUX
# have AUX
# been AUX
# born VERB
# with ADP
# two NUM
# hearts NOUN
# , PUNCT
# neither CCONJ
# one NUM
# agreeing VERB
# where SCONJ
# my PRON
# brain NOUN
# should AUX
# spend VERB
# it PRON
# ' PUNCT
# s PART
# time NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ; PUNCT
# ) PUNCT
# in ADP
# the DET
# evening NOUN
# we PRON
# did AUX
# go VERB
# down ADV
# and CCONJ
# put VERB
# our PRON
# feet NOUN
# in ADP
# the DET
# water NOUN
# - PUNCT
# i PRON
# got VERB
# to ADP
# about ADP
# my PRON
# waist NOUN
# actually ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# feel VERB
# like SCONJ
# i PRON
# am AUX
# in ADV
# over ADP
# my PRON
# head NOUN
# . PUNCT
# . PUNCT
# . PUNCT
# like INTJ
# quicksand NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# would AUX
# go VERB
# over ADP
# to ADP
# his PRON
# house NOUN
# where SCONJ
# his PRON
# grandmother NOUN
# and CCONJ
# mom NOUN
# and CCONJ
# dad NOUN
# lived VERB
# to PART
# play VERB
# ssx NOUN
# tricky ADJ
# and CCONJ
# eat VERB
# pokemon NOUN
# fruit NOUN
# rollups NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# stomach NOUN
# was AUX
# hurting VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# . PUNCT
# . PUNCT
# . PUNCT
# but CCONJ
# raul PROPN
# never ADV
# called VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# accidentally ADV
# drop VERB
# him PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# we PRON
# ' PUNCT
# re ADP
# still ADV
# together ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# thankfully ADV
# only ADV
# a DET
# short ADJ
# ride NOUN
# to ADP
# the DET
# hospital NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# victim NOUN
# - PUNCT
# less ADV
# , PUNCT
# non ADJ
# - PUNCT
# violent ADJ
# crimes NOUN
# shouldn PROPN
# ' PART
# t NOUN
# be AUX
# handled VERB
# so ADV
# harshly ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# leaned VERB
# forward ADV
# in ADP
# my PRON
# seat NOUN
# , PUNCT
# pearing VERB
# though SCONJ
# the DET
# small ADJ
# portion NOUN
# of ADP
# the DET
# windshield NOUN
# that PRON
# was AUX
# clear ADJ
# enough ADV
# to PART
# look VERB
# out ADP
# and CCONJ
# see VERB
# a DET
# wall NOUN
# of ADP
# white ADJ
# reflecting VERB
# my PRON
# lights NOUN
# back ADV
# in ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# sister NOUN
# was AUX
# walking VERB
# backwards ADV
# and CCONJ
# bumped VERB
# her PRON
# back ADV
# into ADP
# the DET
# wall NOUN
# so SCONJ
# the DET
# second ADJ
# shelf NOUN
# or CCONJ
# whatever PRON
# that PRON
# was AUX
# placed VERB
# on ADP
# top NOUN
# of ADP
# the DET
# knobs NOUN
# in ADP
# the DET
# middle NOUN
# fell VERB
# on ADP
# my PRON
# feet NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# aargh NOUN
# , PUNCT
# the DET
# look NOUN
# of ADP
# frenzy NOUN
# must AUX
# have AUX
# been AUX
# written VERB
# all ADV
# over ADP
# my PRON
# face NOUN
# as SCONJ
# i PRON
# tried VERB
# to PART
# corall VERB
# the DET
# older ADJ
# kids NOUN
# and CCONJ
# placate VERB
# my PRON
# little ADJ
# one NUM
# with ADP
# a DET
# granola NOUN
# bar NOUN
# because SCONJ
# it PRON
# was AUX
# dinner NOUN
# time NOUN
# ye NOUN
# know VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# when SCONJ
# mom NOUN
# inquires VERB
# what PRON
# " PUNCT
# the DET
# truth NOUN
# " PUNCT
# is AUX
# , PUNCT
# lisa PROPN
# just ADV
# says VERB
# that SCONJ
# " PUNCT
# you PRON
# will AUX
# know VERB
# eventually ADV
# " PUNCT
# , PUNCT
# and CCONJ
# she PRON
# says VERB
# that SCONJ
# once SCONJ
# she PRON
# learned VERB
# of ADP
# " PUNCT
# the DET
# truth NOUN
# " PUNCT
# , PUNCT
# then ADV
# " PUNCT
# everything PRON
# became VERB
# wonderful ADJ
# " PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# feeling NOUN
# has AUX
# started VERB
# to PART
# come VERB
# back ADV
# to ADP
# my PRON
# eye NOUN
# , PUNCT
# but CCONJ
# i PRON
# still ADV
# ca AUX
# nt PART
# raise VERB
# my PRON
# lip NOUN
# and CCONJ
# actually ADV
# inspect VERB
# the DET
# damage NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# older ADJ
# sister NOUN
# ( PUNCT
# 23 NUM
# at ADP
# the DET
# time NOUN
# ) PUNCT
# is AUX
# a DET
# scumbag NOUN
# stacy NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# then ADV
# she PRON
# tried VERB
# to PART
# , PUNCT
# like INTJ
# , PUNCT
# have VERB
# sex NOUN
# with ADP
# / SYM
# strangle VERB
# everyone PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# longest ADJ
# , PUNCT
# most ADV
# awkward ADJ
# drive NOUN
# i PRON
# ' AUX
# ve AUX
# ever ADV
# taken VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# end NOUN
# of ADP
# story NOUN
# , PUNCT
# right ADJ
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# there PRON
# was VERB
# also ADV
# the DET
# sensation NOUN
# of ADP
# something PRON
# at ADP
# my PRON
# back NOUN
# at ADP
# this DET
# point NOUN
# like ADP
# a DET
# crustacean NOUN
# that PRON
# i PRON
# had VERB
# to PART
# ask VERB
# to PART
# leave VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# i PRON
# ' VERB
# m VERB
# like INTJ
# " PUNCT
# sure ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# block NOUN
# island NOUN
# holds VERB
# a DET
# very ADV
# special ADJ
# place NOUN
# in ADP
# my PRON
# heart NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ok INTJ
# , PUNCT
# so ADV
# my PRON
# pet ADJ
# alligator NOUN
# ' PUNCT
# s NOUN
# tank NOUN
# is AUX
# directly ADV
# across ADP
# from ADP
# my PRON
# pillow NOUN
# . PUNCT
# . PUNCT
# . PUNCT
# the DET
# second ADJ
# i PRON
# opened VERB
# my PRON
# eyes NOUN
# this DET
# morning NOUN
# at ADP
# 6 NUM
# am NOUN
# , PUNCT
# the DET
# absolute ADJ
# first ADJ
# thing NOUN
# i PRON
# see VERB
# is AUX
# my PRON
# alligator NOUN
# in ADP
# the DET
# corner NOUN
# of ADP
# his PRON
# tank NOUN
# staring VERB
# directly ADV
# at ADP
# me PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# anyway ADV
# , PUNCT
# i PRON
# finished VERB
# up ADP
# and CCONJ
# went VERB
# back ADV
# inside ADV
# and CCONJ
# decided VERB
# to PART
# brush VERB
# my PRON
# teeth NOUN
# and CCONJ
# straighten VERB
# my PRON
# shirttail NOUN
# , PUNCT
# which PRON
# had AUX
# gotten VERB
# twisted ADJ
# while SCONJ
# sitting VERB
# on ADP
# the DET
# floor NOUN
# of ADP
# the DET
# hall NOUN
# reading VERB
# for ADP
# two NUM
# hours NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# & CCONJ
# # PROPN
# x SYM
# 26 NUM
# ; PUNCT
# nbsp NOUN
# ; PUNCT
# what PRON
# i PRON
# did AUX
# was AUX
# cut VERB
# the DET
# top NOUN
# off ADP
# of ADP
# a DET
# plastic ADJ
# gallon NOUN
# milk NOUN
# carton PROPN
# leaving VERB
# the DET
# handle NOUN
# then ADV
# by ADP
# standing VERB
# next ADV
# to ADP
# body NOUN
# of ADP
# water NOUN
# or CCONJ
# sometimes ADV
# partially ADV
# in ADP
# it PRON
# i PRON
# could AUX
# get VERB
# a DET
# good ADJ
# dowseing NOUN
# dipping VERB
# the DET
# carton PROPN
# into ADP
# the DET
# water NOUN
# and CCONJ
# then ADV
# dumping VERB
# it PRON
# over ADP
# my PRON
# head NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# welcome VERB
# to ADP
# the DET
# month NOUN
# from ADP
# passive ADJ
# aggressive ADJ
# hell NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# ' AUX
# m AUX
# gon VERB
# na ADP
# absolutely ADV
# ~ PUNCT
# ~ PUNCT
# suck VERB
# ~ PUNCT
# ~ PUNCT
# be AUX
# terrible ADJ
# during ADP
# my PRON
# first ADJ
# sexual ADJ
# experience NOUN
# . PUNCT
# _ PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# doors NOUN
# were AUX
# getting VERB
# ready ADJ
# to PART
# close VERB
# , PUNCT
# and CCONJ
# she PRON
# wasn NOUN
# ' PART
# t NOUN
# in ADP
# yet ADV
# , PUNCT
# so ADV
# i PRON
# wedged VERB
# my PRON
# foot NOUN
# in ADP
# the DET
# bottom NOUN
# of ADP
# the DET
# door NOUN
# to PART
# hold VERB
# it PRON
# open ADJ
# for ADP
# her PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# clint NOUN
# and CCONJ
# i PRON
# went VERB
# up ADV
# and CCONJ
# down ADV
# with ADP
# that DET
# weight NOUN
# for ADP
# at ADV
# least ADV
# three NUM
# or CCONJ
# four NUM
# reps NOUN
# after SCONJ
# i PRON
# thought VERB
# my PRON
# legs NOUN
# were AUX
# shot VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# have VERB
# a DET
# floor NOUN
# shift NOUN
# in ADP
# the DET
# morning NOUN
# , PUNCT
# hopefully ADV
# without ADP
# my PRON
# nose NOUN
# being AUX
# stuffy ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# can AUX
# ' VERB
# t NOUN
# breathe INTJ
# right INTJ
# , PUNCT
# my PRON
# head NOUN
# has AUX
# been AUX
# stuffed VERB
# up ADP
# for ADP
# three NUM
# months NOUN
# , PUNCT
# i PRON
# have AUX
# whacked VERB
# out ADP
# dreams NOUN
# , PUNCT
# can AUX
# ' PUNCT
# t NOUN
# sleep NOUN
# , PUNCT
# i PRON
# ' VERB
# m VERB
# just ADV
# . PUNCT
# . PUNCT
# . PUNCT
# i PRON
# ' VERB
# m VERB
# . PUNCT
# . PUNCT
# . PUNCT
# i PRON
# feel VERB
# like SCONJ
# i PRON
# ' AUX
# m AUX
# breaking VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# getting VERB
# out ADP
# of ADP
# the DET
# house NOUN
# put VERB
# a DET
# smile NOUN
# on ADP
# my PRON
# face NOUN
# , PUNCT
# that PRON
# and CCONJ
# the DET
# fact NOUN
# that SCONJ
# she PRON
# had AUX
# some DET
# wicked ADJ
# old ADJ
# music NOUN
# on ADP
# her PRON
# ipod ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# heart NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# entire ADJ
# summer NOUN
# is AUX
# going VERB
# to PART
# pass VERB
# by ADP
# with ADP
# a DET
# blink NOUN
# of ADP
# my PRON
# eye NOUN
# because SCONJ
# i PRON
# ' AUX
# ve AUX
# got AUX
# so ADV
# much ADJ
# going VERB
# on ADP
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# < X
# < X
# < X
# using VERB
# my PRON
# brain NOUN
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# is AUX
# stuck VERB
# there ADV
# in ADP
# the DET
# back NOUN
# of ADP
# my PRON
# head NOUN
# with ADP
# some DET
# other ADJ
# nasty ADJ
# stuff NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# put VERB
# my PRON
# hand NOUN
# on ADP
# its PRON
# tail NOUN
# to ADP
# pet ADJ
# it PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# beyond ADP
# furious ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# oh INTJ
# , PUNCT
# and CCONJ
# i PRON
# noticed VERB
# an DET
# odd ADJ
# effect NOUN
# from ADP
# eating VERB
# ripe ADJ
# honeydew NOUN
# melon NOUN
# ; PUNCT
# this DET
# raspy NOUN
# , PUNCT
# raw ADJ
# feeling NOUN
# in ADP
# my PRON
# chest NOUN
# , PUNCT
# like ADP
# a DET
# cold NOUN
# was AUX
# coming VERB
# on ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# your PRON
# sister NOUN
# is AUX
# a DET
# heavy ADJ
# sleeper NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# didn NOUN
# ' PUNCT
# t NOUN
# see VERB
# it PRON
# through ADP
# but CCONJ
# what PRON
# i PRON
# did AUX
# see VERB
# when SCONJ
# i PRON
# lifted VERB
# my PRON
# head NOUN
# was AUX
# my PRON
# wife NOUN
# coming VERB
# up ADP
# the DET
# street NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# always ADV
# hiding VERB
# my PRON
# eyes NOUN
# welling VERB
# up ADP
# by ADP
# yawning VERB
# so ADV
# it PRON
# seemed VERB
# like SCONJ
# they PRON
# were AUX
# just ADV
# tearing VERB
# from ADP
# that PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# in ADP
# between ADP
# my PRON
# toes NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# tears NOUN
# welled VERB
# up ADP
# in ADP
# my PRON
# eyes NOUN
# , PUNCT
# but CCONJ
# none NOUN
# fell VERB
# out ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# swarms NOUN
# of ADP
# people NOUN
# wandering VERB
# around ADP
# confused ADJ
# and CCONJ
# unaware ADJ
# of ADP
# where SCONJ
# they PRON
# ' PUNCT
# re ADP
# going VERB
# , PUNCT
# cutting VERB
# people NOUN
# short ADJ
# as SCONJ
# they PRON
# wander VERB
# into ADP
# burger NOUN
# king NOUN
# and CCONJ
# other ADJ
# such ADJ
# stores NOUN
# on ADP
# the DET
# other ADJ
# side NOUN
# of ADP
# the DET
# corridor NOUN
# - PUNCT
# completely ADV
# unaware ADJ
# of ADP
# the DET
# fact NOUN
# that SCONJ
# they PRON
# literally ADV
# almost ADV
# made VERB
# me PRON
# drop VERB
# everything PRON
# i PRON
# ' AUX
# m AUX
# carrying VERB
# and CCONJ
# fall VERB
# flat ADJ
# on ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# ' VERB
# m VERB
# a DET
# highly ADV
# skeptical ADJ
# , PUNCT
# scientific ADJ
# person NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# after ADP
# standing VERB
# in ADP
# a DET
# few ADJ
# times NOUN
# in ADP
# the DET
# past NOUN
# his PRON
# buddy NOUN
# asks VERB
# again ADV
# but CCONJ
# warns VERB
# him PRON
# that SCONJ
# it PRON
# is AUX
# the DET
# full ADJ
# moon NOUN
# and CCONJ
# it PRON
# won VERB
# ' PART
# t NOUN
# be AUX
# like ADP
# the DET
# last ADJ
# times NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# said VERB
# the DET
# first ADJ
# thing NOUN
# that PRON
# came VERB
# into ADP
# my PRON
# head NOUN
# , PUNCT
# ` PUNCT
# ciao PROPN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# what PRON
# is AUX
# it PRON
# about ADP
# this DET
# winter NOUN
# that PRON
# is AUX
# making VERB
# me PRON
# literally ADV
# sick ADJ
# to ADP
# my PRON
# stomach NOUN
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# song NOUN
# ` PUNCT
# ` PUNCT
# poor ADJ
# places NOUN
# ' PUNCT
# ' PUNCT
# is AUX
# ironically ADV
# seeping VERB
# out ADP
# of ADP
# my PRON
# speakers NOUN
# and CCONJ
# into ADP
# my PRON
# ears NOUN
# : PUNCT
# it PRON
# ' PUNCT
# s VERB
# hot ADJ
# in ADP
# the DET
# poor ADJ
# places NOUN
# tonight NOUN
# / PUNCT
# i PRON
# ' AUX
# m AUX
# not PART
# going VERB
# outside ADV
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# we PRON
# had AUX
# obviously ADV
# done VERB
# this PRON
# before ADV
# , PUNCT
# but CCONJ
# this DET
# time NOUN
# something PRON
# was AUX
# different ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# not PART
# hardcore ADJ
# accidental ADJ
# racism NOUN
# , PUNCT
# but CCONJ
# it PRON
# fits VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# cried VERB
# my PRON
# eyes NOUN
# out ADP
# , PUNCT
# longing VERB
# for ADP
# the DET
# days NOUN
# just ADV
# a DET
# mere ADJ
# 10 NUM
# 1 NUM
# / SYM
# 2 NUM
# months NOUN
# or CCONJ
# so ADV
# ago ADV
# when SCONJ
# i PRON
# called VERB
# this DET
# ` PUNCT
# ` PUNCT
# home NOUN
# ' PUNCT
# ' PUNCT
# and CCONJ
# knew VERB
# that SCONJ
# i PRON
# had VERB
# a DET
# safe ADJ
# haven NOUN
# to PART
# rest VERB
# my PRON
# head NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# friend NOUN
# and CCONJ
# i PRON
# were AUX
# walking VERB
# home ADV
# from ADP
# school NOUN
# as ADP
# per ADP
# usual ADJ
# as SCONJ
# we PRON
# lived VERB
# close ADV
# to ADP
# each DET
# other ADJ
# and CCONJ
# this PRON
# was AUX
# the DET
# normal ADJ
# routine NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# a DET
# fraying VERB
# rope NOUN
# stretches VERB
# down ADP
# from ADP
# the DET
# rafters NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# had VERB
# to PART
# chord VERB
# with ADP
# my PRON
# thumb NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# after ADP
# that DET
# first ADJ
# big ADJ
# experience NOUN
# i PRON
# started VERB
# doing VERB
# some DET
# research NOUN
# because SCONJ
# i PRON
# was AUX
# so ADV
# confused ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# heart NOUN
# was AUX
# beating VERB
# fast ADV
# from ADP
# excitement NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# nose NOUN
# is AUX
# currently ADV
# upset ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# way NOUN
# i PRON
# was AUX
# positioned VERB
# with ADP
# the DET
# air NOUN
# moving VERB
# made VERB
# it PRON
# hard ADJ
# to PART
# not PART
# breath VERB
# through ADP
# my PRON
# mouth NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# & CCONJ
# gt PROPN
# ; PUNCT
# me PRON
# : PUNCT
# " PUNCT
# wait VERB
# , PUNCT
# really ADV
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# has AUX
# sat VERB
# with ADP
# me PRON
# , PUNCT
# back ADV
# in ADP
# the DET
# pit NOUN
# of ADP
# my PRON
# stomach NOUN
# since SCONJ
# sunday PROPN
# night NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# went VERB
# at ADP
# it PRON
# twice ADV
# , PUNCT
# until SCONJ
# the DET
# muscles NOUN
# around ADP
# my PRON
# mouth NOUN
# hurt VERB
# and CCONJ
# my PRON
# innards NOUN
# almost ADV
# came VERB
# out ADP
# together ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# tried VERB
# to PART
# be AUX
# an DET
# easy ADJ
# going VERB
# bride NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ( PUNCT
# you PRON
# see VERB
# , PUNCT
# i PRON
# have VERB
# these PRON
# afi PROPN
# patches NOUN
# that SCONJ
# i PRON
# bought VERB
# in ADP
# 2004 NUM
# and CCONJ
# i PRON
# had VERB
# no PRON
# where SCONJ
# to PART
# put VERB
# them PRON
# ) PUNCT
# yesterday NOUN
# i PRON
# bought VERB
# this DET
# neato NOUN
# bag NOUN
# and CCONJ
# i PRON
# said VERB
# to ADP
# my PRON
# brain NOUN
# ' PUNCT
# ' PUNCT
# i PRON
# can AUX
# put VERB
# my PRON
# patches NOUN
# on ADP
# this DET
# here ADJ
# bag NOUN
# . PUNCT
# ' PUNCT
# ' PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# this PRON
# is AUX
# so ADV
# odd ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# takes VERB
# them PRON
# 6 NUM
# guys NOUN
# , PUNCT
# all DET
# firefighters NOUN
# mind VERB
# , PUNCT
# and CCONJ
# one NUM
# old ADJ
# schoolteacher NOUN
# , PUNCT
# to PART
# lift VERB
# this DET
# oak NOUN
# dresser NOUN
# off ADP
# meridian PROPN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# about ADV
# ten NUM
# years NOUN
# ago ADV
# , PUNCT
# he PRON
# passed VERB
# away ADV
# from ADP
# a DET
# severe ADJ
# brain NOUN
# tumor NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# best ADJ
# part NOUN
# however ADV
# was AUX
# when SCONJ
# she PRON
# jumped VERB
# into ADP
# the DET
# pictures NOUN
# and CCONJ
# pushed VERB
# the DET
# dog NOUN
# into ADP
# my PRON
# hands NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# can AUX
# ' AUX
# t NOUN
# wait VERB
# to PART
# be AUX
# in ADP
# another DET
# wedding NOUN
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# black ADJ
# eyed ADJ
# kids NOUN
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# look VERB
# at ADP
# them PRON
# once ADV
# and CCONJ
# that PRON
# ' PUNCT
# s AUX
# it PRON
# whispered VERB
# my PRON
# wife NOUN
# in ADP
# my PRON
# ears NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# and CCONJ
# my PRON
# brain NOUN
# can AUX
# think VERB
# up ADP
# some DET
# pretty ADV
# horrible ADJ
# ailments NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# legs NOUN
# felt VERB
# sluggish ADJ
# , PUNCT
# my PRON
# calves NOUN
# were AUX
# burning VERB
# , PUNCT
# my PRON
# right ADJ
# foot NOUN
# was AUX
# pinched VERB
# , PUNCT
# and CCONJ
# i PRON
# couldn PROPN
# ' PUNCT
# t NOUN
# settle VERB
# into ADP
# my PRON
# typical ADJ
# breathing NOUN
# pattern NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# can AUX
# ' VERB
# t NOUN
# move VERB
# , PUNCT
# my PRON
# hand NOUN
# is AUX
# stuck ADJ
# , PUNCT
# i PRON
# ' AUX
# m AUX
# making VERB
# weird ADJ
# noises NOUN
# and CCONJ
# my PRON
# mom NOUN
# is AUX
# screaming VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ) PUNCT
# i PRON
# started VERB
# to PART
# teach VERB
# myself PRON
# japanese ADJ
# , PUNCT
# and CCONJ
# just ADV
# couldn PROPN
# ' PUNCT
# t NOUN
# shake VERB
# the DET
# feeling NOUN
# that SCONJ
# i PRON
# was AUX
# supposed VERB
# to PART
# live VERB
# there ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# this PRON
# was AUX
# fairly ADV
# recently ADV
# . PUNCT
# . PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# her PRON
# nose NOUN
# was AUX
# broken VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# wow INTJ
# , PUNCT
# that PRON
# is AUX
# really ADV
# interesting ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# and CCONJ
# burst VERB
# into ADP
# tears NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# never ADV
# been AUX
# so ADV
# close ADJ
# to ADP
# a DET
# group NOUN
# ass NOUN
# - PUNCT
# wooping VERB
# in ADP
# my PRON
# life NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# heart NOUN
# sank VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# actually ADV
# what PRON
# ' AUX
# s AUX
# going VERB
# on ADP
# in ADP
# my PRON
# head NOUN
# is AUX
# a DET
# lot NOUN
# of ADP
# congestion NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# he PRON
# also ADV
# worse ADJ
# black ADJ
# gloves NOUN
# and CCONJ
# a DET
# black ADJ
# ski NOUN
# mask NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# police NOUN
# were AUX
# called VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# overflowed VERB
# and CCONJ
# brown ADJ
# shitty PROPN
# diarrhea NOUN
# water NOUN
# came AUX
# flooding VERB
# under ADP
# the DET
# stall NOUN
# wall NOUN
# into ADP
# my PRON
# wife NOUN
# ' PUNCT
# s NOUN
# stall NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# rip VERB
# my PRON
# heart NOUN
# out ADP
# and CCONJ
# stomp ADV
# that PRON
# sucker VERB
# flat ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# was AUX
# not PART
# happy ADJ
# with ADP
# the DET
# waking VERB
# up ADP
# , PUNCT
# but CCONJ
# was AUX
# awake ADJ
# because SCONJ
# my PRON
# hands NOUN
# were AUX
# on ADP
# fire NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# one NOUN
# screamed VERB
# out ADP
# that SCONJ
# it PRON
# was AUX
# screwed VERB
# up ADP
# , PUNCT
# to PART
# which PRON
# another PRON
# replied VERB
# " PUNCT
# to ADP
# the DET
# max PROPN
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# brought VERB
# by ADP
# to ADP
# reality NOUN
# when SCONJ
# noona PROPN
# hit VERB
# my PRON
# arm NOUN
# lightly ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# remember VERB
# the DET
# sweat NOUN
# burning VERB
# in ADP
# my PRON
# eyes NOUN
# and CCONJ
# trying VERB
# to PART
# control VERB
# my PRON
# breathing NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# untie VERB
# my PRON
# bear NOUN
# bag NOUN
# and CCONJ
# grab VERB
# some DET
# food NOUN
# inside ADP
# it PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# got VERB
# close ADJ
# enough ADV
# to PART
# feel VERB
# some PRON
# of ADP
# the DET
# spray NOUN
# from ADP
# the DET
# falls NOUN
# landing VERB
# on ADP
# my PRON
# lips NOUN
# and CCONJ
# glasses NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# walk VERB
# right ADV
# over ADV
# to ADP
# the DET
# tv NOUN
# , PUNCT
# stand VERB
# face NOUN
# to PART
# face VERB
# with ADP
# it PRON
# , PUNCT
# and CCONJ
# begin VERB
# to PART
# point VERB
# at ADP
# the DET
# little ADJ
# number NOUN
# areas NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# wake VERB
# up ADP
# very ADV
# easily ADV
# to ADP
# sounds VERB
# so ADV
# i PRON
# ' VERB
# m VERB
# not PART
# overly ADV
# concerned ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# and CCONJ
# i PRON
# laughed VERB
# like ADP
# this PRON
# : PUNCT
# garhahagar PROPN
# , PUNCT
# because SCONJ
# my PRON
# mouth NOUN
# was AUX
# full ADJ
# of ADP
# cotton NOUN
# and CCONJ
# shit NOUN
# to PART
# bite VERB
# down ADP
# on ADP
# and CCONJ
# sharp ADJ
# objects NOUN
# and CCONJ
# drills NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# its PRON
# very ADV
# dark ADJ
# and CCONJ
# foggy ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# was AUX
# late ADJ
# and CCONJ
# they PRON
# were AUX
# asleep ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# a DET
# deep ADJ
# thud NOUN
# sound NOUN
# in ADP
# the DET
# room NOUN
# and CCONJ
# a DET
# grin NOUN
# spread VERB
# across ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# dad NOUN
# is AUX
# a DET
# minister NOUN
# and CCONJ
# part NOUN
# of ADP
# his PRON
# duties NOUN
# is AUX
# visiting VERB
# the DET
# sick ADJ
# and CCONJ
# dying VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# we PRON
# moved VERB
# to ADP
# a DET
# labor NOUN
# and CCONJ
# delivery NOUN
# room NOUN
# and CCONJ
# i PRON
# labored VERB
# mostly ADV
# on ADP
# my PRON
# hands NOUN
# and CCONJ
# knees NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# ' PUNCT
# s VERB
# so ADV
# stressful ADJ
# but CCONJ
# i PRON
# ' PUNCT
# d VERB
# never ADV
# wanna NOUN
# be AUX
# with ADP
# anyone PRON
# else ADV
# and CCONJ
# i PRON
# ' VERB
# d INTJ
# marry VERB
# her PRON
# this DET
# minute NOUN
# if SCONJ
# the DET
# financial ADJ
# made VERB
# sense NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# i PRON
# don PROPN
# ' PUNCT
# t NOUN
# have VERB
# time NOUN
# to PART
# arrest VERB
# drunk ADJ
# drivers NOUN
# because SCONJ
# of ADP
# all DET
# the DET
# murders NOUN
# , PUNCT
# rapes NOUN
# , PUNCT
# and CCONJ
# robberies NOUN
# we PRON
# have VERB
# to PART
# deal VERB
# with ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# looked VERB
# at ADP
# my PRON
# wrist NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# arch NOUN
# stop VERB
# your PRON
# progression NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# this DET
# ' PUNCT
# star NOUN
# ' PUNCT
# , PUNCT
# starts VERB
# to PART
# move VERB
# across ADP
# the DET
# sky NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# and CCONJ
# my PRON
# feet NOUN
# hurt VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# so ADV
# i PRON
# cried VERB
# my PRON
# eyes NOUN
# out ADP
# and CCONJ
# did VERB
# the DET
# drawing NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# they PRON
# were AUX
# coal NOUN
# black NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# mouth NOUN
# fell VERB
# open ADJ
# ` PUNCT
# ` PUNCT
# no INTJ
# , PUNCT
# no INTJ
# , PUNCT
# no INTJ
# . PUNCT
# . PUNCT
# . PUNCT
# i PRON
# . PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# you PRON
# can AUX
# barely ADV
# make VERB
# out ADP
# your PRON
# daughter NOUN
# ' PUNCT
# s PART
# pale ADJ
# form NOUN
# in ADP
# the DET
# darkness NOUN
# of ADP
# your PRON
# room NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# but CCONJ
# after ADP
# blinking VERB
# my PRON
# eyes NOUN
# for ADP
# a DET
# few ADJ
# times NOUN
# lepas VERB
# tu PROPN
# tampar NOUN
# - PUNCT
# tampar NOUN
# muka PROPN
# sikit PROPN
# , PUNCT
# memang PROPN
# sah PROPN
# la PROPN
# yang PROPN
# penghantar PROPN
# itu PROPN
# hanis PROPN
# zalikha PROPN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# slowly ADV
# rising VERB
# to ADP
# my PRON
# feet NOUN
# i PRON
# came VERB
# to ADP
# the DET
# conclusion NOUN
# that SCONJ
# sometimes ADV
# being AUX
# alone ADV
# meant VERB
# surviving VERB
# for ADP
# myself PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# noticed VERB
# this DET
# months NOUN
# after ADP
# moving VERB
# in ADV
# and CCONJ
# doing VERB
# all PRON
# of ADP
# my PRON
# basic ADJ
# routines NOUN
# in ADP
# my PRON
# room NOUN
# naked ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# know VERB
# not PART
# why SCONJ
# , PUNCT
# i PRON
# wipe VERB
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# was AUX
# rather ADV
# insulting ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# born VERB
# without ADP
# the DET
# compassion NOUN
# chromosome NOUN
# , PUNCT
# or CCONJ
# i PRON
# could AUX
# have AUX
# been AUX
# born VERB
# with ADP
# two NUM
# hearts NOUN
# , PUNCT
# neither CCONJ
# one NUM
# agreeing VERB
# where SCONJ
# my PRON
# brain NOUN
# should AUX
# spend VERB
# it PRON
# ' PUNCT
# s PART
# time NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ; PUNCT
# ) PUNCT
# in ADP
# the DET
# evening NOUN
# we PRON
# did AUX
# go VERB
# down ADV
# and CCONJ
# put VERB
# our PRON
# feet NOUN
# in ADP
# the DET
# water NOUN
# - PUNCT
# i PRON
# got VERB
# to ADP
# about ADP
# my PRON
# waist NOUN
# actually ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# feel VERB
# like SCONJ
# i PRON
# am AUX
# in ADV
# over ADP
# my PRON
# head NOUN
# . PUNCT
# . PUNCT
# . PUNCT
# like INTJ
# quicksand NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# would AUX
# go VERB
# over ADP
# to ADP
# his PRON
# house NOUN
# where SCONJ
# his PRON
# grandmother NOUN
# and CCONJ
# mom NOUN
# and CCONJ
# dad NOUN
# lived VERB
# to PART
# play VERB
# ssx NOUN
# tricky ADJ
# and CCONJ
# eat VERB
# pokemon NOUN
# fruit NOUN
# rollups NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# stomach NOUN
# was AUX
# hurting VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# . PUNCT
# . PUNCT
# . PUNCT
# but CCONJ
# raul PROPN
# never ADV
# called VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# accidentally ADV
# drop VERB
# him PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# we PRON
# ' PUNCT
# re ADP
# still ADV
# together ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# thankfully ADV
# only ADV
# a DET
# short ADJ
# ride NOUN
# to ADP
# the DET
# hospital NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# victim NOUN
# - PUNCT
# less ADV
# , PUNCT
# non ADJ
# - PUNCT
# violent ADJ
# crimes NOUN
# shouldn PROPN
# ' PART
# t NOUN
# be AUX
# handled VERB
# so ADV
# harshly ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# leaned VERB
# forward ADV
# in ADP
# my PRON
# seat NOUN
# , PUNCT
# pearing VERB
# though SCONJ
# the DET
# small ADJ
# portion NOUN
# of ADP
# the DET
# windshield NOUN
# that PRON
# was AUX
# clear ADJ
# enough ADV
# to PART
# look VERB
# out ADP
# and CCONJ
# see VERB
# a DET
# wall NOUN
# of ADP
# white ADJ
# reflecting VERB
# my PRON
# lights NOUN
# back ADV
# in ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# sister NOUN
# was AUX
# walking VERB
# backwards ADV
# and CCONJ
# bumped VERB
# her PRON
# back ADV
# into ADP
# the DET
# wall NOUN
# so SCONJ
# the DET
# second ADJ
# shelf NOUN
# or CCONJ
# whatever PRON
# that PRON
# was AUX
# placed VERB
# on ADP
# top NOUN
# of ADP
# the DET
# knobs NOUN
# in ADP
# the DET
# middle NOUN
# fell VERB
# on ADP
# my PRON
# feet NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# aargh NOUN
# , PUNCT
# the DET
# look NOUN
# of ADP
# frenzy NOUN
# must AUX
# have AUX
# been AUX
# written VERB
# all ADV
# over ADP
# my PRON
# face NOUN
# as SCONJ
# i PRON
# tried VERB
# to PART
# corall VERB
# the DET
# older ADJ
# kids NOUN
# and CCONJ
# placate VERB
# my PRON
# little ADJ
# one NUM
# with ADP
# a DET
# granola NOUN
# bar NOUN
# because SCONJ
# it PRON
# was AUX
# dinner NOUN
# time NOUN
# ye NOUN
# know VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# when SCONJ
# mom NOUN
# inquires VERB
# what PRON
# " PUNCT
# the DET
# truth NOUN
# " PUNCT
# is AUX
# , PUNCT
# lisa PROPN
# just ADV
# says VERB
# that SCONJ
# " PUNCT
# you PRON
# will AUX
# know VERB
# eventually ADV
# " PUNCT
# , PUNCT
# and CCONJ
# she PRON
# says VERB
# that SCONJ
# once SCONJ
# she PRON
# learned VERB
# of ADP
# " PUNCT
# the DET
# truth NOUN
# " PUNCT
# , PUNCT
# then ADV
# " PUNCT
# everything PRON
# became VERB
# wonderful ADJ
# " PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# feeling NOUN
# has AUX
# started VERB
# to PART
# come VERB
# back ADV
# to ADP
# my PRON
# eye NOUN
# , PUNCT
# but CCONJ
# i PRON
# still ADV
# ca AUX
# nt PART
# raise VERB
# my PRON
# lip NOUN
# and CCONJ
# actually ADV
# inspect VERB
# the DET
# damage NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# older ADJ
# sister NOUN
# ( PUNCT
# 23 NUM
# at ADP
# the DET
# time NOUN
# ) PUNCT
# is AUX
# a DET
# scumbag NOUN
# stacy NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# then ADV
# she PRON
# tried VERB
# to PART
# , PUNCT
# like INTJ
# , PUNCT
# have VERB
# sex NOUN
# with ADP
# / SYM
# strangle VERB
# everyone PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# longest ADJ
# , PUNCT
# most ADV
# awkward ADJ
# drive NOUN
# i PRON
# ' AUX
# ve AUX
# ever ADV
# taken VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# end NOUN
# of ADP
# story NOUN
# , PUNCT
# right ADJ
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# there PRON
# was VERB
# also ADV
# the DET
# sensation NOUN
# of ADP
# something PRON
# at ADP
# my PRON
# back NOUN
# at ADP
# this DET
# point NOUN
# like ADP
# a DET
# crustacean NOUN
# that PRON
# i PRON
# had VERB
# to PART
# ask VERB
# to PART
# leave VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# i PRON
# ' VERB
# m VERB
# like INTJ
# " PUNCT
# sure ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# block NOUN
# island NOUN
# holds VERB
# a DET
# very ADV
# special ADJ
# place NOUN
# in ADP
# my PRON
# heart NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ok INTJ
# , PUNCT
# so ADV
# my PRON
# pet ADJ
# alligator NOUN
# ' PUNCT
# s NOUN
# tank NOUN
# is AUX
# directly ADV
# across ADP
# from ADP
# my PRON
# pillow NOUN
# . PUNCT
# . PUNCT
# . PUNCT
# the DET
# second ADJ
# i PRON
# opened VERB
# my PRON
# eyes NOUN
# this DET
# morning NOUN
# at ADP
# 6 NUM
# am NOUN
# , PUNCT
# the DET
# absolute ADJ
# first ADJ
# thing NOUN
# i PRON
# see VERB
# is AUX
# my PRON
# alligator NOUN
# in ADP
# the DET
# corner NOUN
# of ADP
# his PRON
# tank NOUN
# staring VERB
# directly ADV
# at ADP
# me PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# anyway ADV
# , PUNCT
# i PRON
# finished VERB
# up ADP
# and CCONJ
# went VERB
# back ADV
# inside ADV
# and CCONJ
# decided VERB
# to PART
# brush VERB
# my PRON
# teeth NOUN
# and CCONJ
# straighten VERB
# my PRON
# shirttail NOUN
# , PUNCT
# which PRON
# had AUX
# gotten VERB
# twisted ADJ
# while SCONJ
# sitting VERB
# on ADP
# the DET
# floor NOUN
# of ADP
# the DET
# hall NOUN
# reading VERB
# for ADP
# two NUM
# hours NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# & CCONJ
# # PROPN
# x SYM
# 26 NUM
# ; PUNCT
# nbsp NOUN
# ; PUNCT
# what PRON
# i PRON
# did AUX
# was AUX
# cut VERB
# the DET
# top NOUN
# off ADP
# of ADP
# a DET
# plastic ADJ
# gallon NOUN
# milk NOUN
# carton PROPN
# leaving VERB
# the DET
# handle NOUN
# then ADV
# by ADP
# standing VERB
# next ADV
# to ADP
# body NOUN
# of ADP
# water NOUN
# or CCONJ
# sometimes ADV
# partially ADV
# in ADP
# it PRON
# i PRON
# could AUX
# get VERB
# a DET
# good ADJ
# dowseing NOUN
# dipping VERB
# the DET
# carton PROPN
# into ADP
# the DET
# water NOUN
# and CCONJ
# then ADV
# dumping VERB
# it PRON
# over ADP
# my PRON
# head NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# welcome VERB
# to ADP
# the DET
# month NOUN
# from ADP
# passive ADJ
# aggressive ADJ
# hell NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# ' AUX
# m AUX
# gon VERB
# na ADP
# absolutely ADV
# ~ PUNCT
# ~ PUNCT
# suck VERB
# ~ PUNCT
# ~ PUNCT
# be AUX
# terrible ADJ
# during ADP
# my PRON
# first ADJ
# sexual ADJ
# experience NOUN
# . PUNCT
# _ PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# doors NOUN
# were AUX
# getting VERB
# ready ADJ
# to PART
# close VERB
# , PUNCT
# and CCONJ
# she PRON
# wasn NOUN
# ' PART
# t NOUN
# in ADP
# yet ADV
# , PUNCT
# so ADV
# i PRON
# wedged VERB
# my PRON
# foot NOUN
# in ADP
# the DET
# bottom NOUN
# of ADP
# the DET
# door NOUN
# to PART
# hold VERB
# it PRON
# open ADJ
# for ADP
# her PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# clint NOUN
# and CCONJ
# i PRON
# went VERB
# up ADV
# and CCONJ
# down ADV
# with ADP
# that DET
# weight NOUN
# for ADP
# at ADV
# least ADV
# three NUM
# or CCONJ
# four NUM
# reps NOUN
# after SCONJ
# i PRON
# thought VERB
# my PRON
# legs NOUN
# were AUX
# shot VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# have VERB
# a DET
# floor NOUN
# shift NOUN
# in ADP
# the DET
# morning NOUN
# , PUNCT
# hopefully ADV
# without ADP
# my PRON
# nose NOUN
# being AUX
# stuffy ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# can AUX
# ' VERB
# t NOUN
# breathe INTJ
# right INTJ
# , PUNCT
# my PRON
# head NOUN
# has AUX
# been AUX
# stuffed VERB
# up ADP
# for ADP
# three NUM
# months NOUN
# , PUNCT
# i PRON
# have AUX
# whacked VERB
# out ADP
# dreams NOUN
# , PUNCT
# can AUX
# ' PUNCT
# t NOUN
# sleep NOUN
# , PUNCT
# i PRON
# ' VERB
# m VERB
# just ADV
# . PUNCT
# . PUNCT
# . PUNCT
# i PRON
# ' VERB
# m VERB
# . PUNCT
# . PUNCT
# . PUNCT
# i PRON
# feel VERB
# like SCONJ
# i PRON
# ' AUX
# m AUX
# breaking VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# getting VERB
# out ADP
# of ADP
# the DET
# house NOUN
# put VERB
# a DET
# smile NOUN
# on ADP
# my PRON
# face NOUN
# , PUNCT
# that PRON
# and CCONJ
# the DET
# fact NOUN
# that SCONJ
# she PRON
# had AUX
# some DET
# wicked ADJ
# old ADJ
# music NOUN
# on ADP
# her PRON
# ipod ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# heart NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# entire ADJ
# summer NOUN
# is AUX
# going VERB
# to PART
# pass VERB
# by ADP
# with ADP
# a DET
# blink NOUN
# of ADP
# my PRON
# eye NOUN
# because SCONJ
# i PRON
# ' AUX
# ve AUX
# got AUX
# so ADV
# much ADJ
# going VERB
# on ADP
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# < X
# < X
# < X
# using VERB
# my PRON
# brain NOUN
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# is AUX
# stuck VERB
# there ADV
# in ADP
# the DET
# back NOUN
# of ADP
# my PRON
# head NOUN
# with ADP
# some DET
# other ADJ
# nasty ADJ
# stuff NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# put VERB
# my PRON
# hand NOUN
# on ADP
# its PRON
# tail NOUN
# to ADP
# pet ADJ
# it PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# beyond ADP
# furious ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# oh INTJ
# , PUNCT
# and CCONJ
# i PRON
# noticed VERB
# an DET
# odd ADJ
# effect NOUN
# from ADP
# eating VERB
# ripe ADJ
# honeydew NOUN
# melon NOUN
# ; PUNCT
# this DET
# raspy NOUN
# , PUNCT
# raw ADJ
# feeling NOUN
# in ADP
# my PRON
# chest NOUN
# , PUNCT
# like ADP
# a DET
# cold NOUN
# was AUX
# coming VERB
# on ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# your PRON
# sister NOUN
# is AUX
# a DET
# heavy ADJ
# sleeper NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# didn NOUN
# ' PUNCT
# t NOUN
# see VERB
# it PRON
# through ADP
# but CCONJ
# what PRON
# i PRON
# did AUX
# see VERB
# when SCONJ
# i PRON
# lifted VERB
# my PRON
# head NOUN
# was AUX
# my PRON
# wife NOUN
# coming VERB
# up ADP
# the DET
# street NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# always ADV
# hiding VERB
# my PRON
# eyes NOUN
# welling VERB
# up ADP
# by ADP
# yawning VERB
# so ADV
# it PRON
# seemed VERB
# like SCONJ
# they PRON
# were AUX
# just ADV
# tearing VERB
# from ADP
# that PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# in ADP
# between ADP
# my PRON
# toes NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# tears NOUN
# welled VERB
# up ADP
# in ADP
# my PRON
# eyes NOUN
# , PUNCT
# but CCONJ
# none NOUN
# fell VERB
# out ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# swarms NOUN
# of ADP
# people NOUN
# wandering VERB
# around ADP
# confused ADJ
# and CCONJ
# unaware ADJ
# of ADP
# where SCONJ
# they PRON
# ' PUNCT
# re ADP
# going VERB
# , PUNCT
# cutting VERB
# people NOUN
# short ADJ
# as SCONJ
# they PRON
# wander VERB
# into ADP
# burger NOUN
# king NOUN
# and CCONJ
# other ADJ
# such ADJ
# stores NOUN
# on ADP
# the DET
# other ADJ
# side NOUN
# of ADP
# the DET
# corridor NOUN
# - PUNCT
# completely ADV
# unaware ADJ
# of ADP
# the DET
# fact NOUN
# that SCONJ
# they PRON
# literally ADV
# almost ADV
# made VERB
# me PRON
# drop VERB
# everything PRON
# i PRON
# ' AUX
# m AUX
# carrying VERB
# and CCONJ
# fall VERB
# flat ADJ
# on ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# ' VERB
# m VERB
# a DET
# highly ADV
# skeptical ADJ
# , PUNCT
# scientific ADJ
# person NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# after ADP
# standing VERB
# in ADP
# a DET
# few ADJ
# times NOUN
# in ADP
# the DET
# past NOUN
# his PRON
# buddy NOUN
# asks VERB
# again ADV
# but CCONJ
# warns VERB
# him PRON
# that SCONJ
# it PRON
# is AUX
# the DET
# full ADJ
# moon NOUN
# and CCONJ
# it PRON
# won VERB
# ' PART
# t NOUN
# be AUX
# like ADP
# the DET
# last ADJ
# times NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# said VERB
# the DET
# first ADJ
# thing NOUN
# that PRON
# came VERB
# into ADP
# my PRON
# head NOUN
# , PUNCT
# ` PUNCT
# ciao PROPN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# what PRON
# is AUX
# it PRON
# about ADP
# this DET
# winter NOUN
# that PRON
# is AUX
# making VERB
# me PRON
# literally ADV
# sick ADJ
# to ADP
# my PRON
# stomach NOUN
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# song NOUN
# ` PUNCT
# ` PUNCT
# poor ADJ
# places NOUN
# ' PUNCT
# ' PUNCT
# is AUX
# ironically ADV
# seeping VERB
# out ADP
# of ADP
# my PRON
# speakers NOUN
# and CCONJ
# into ADP
# my PRON
# ears NOUN
# : PUNCT
# it PRON
# ' PUNCT
# s VERB
# hot ADJ
# in ADP
# the DET
# poor ADJ
# places NOUN
# tonight NOUN
# / PUNCT
# i PRON
# ' AUX
# m AUX
# not PART
# going VERB
# outside ADV
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# we PRON
# had AUX
# obviously ADV
# done VERB
# this PRON
# before ADV
# , PUNCT
# but CCONJ
# this DET
# time NOUN
# something PRON
# was AUX
# different ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# not PART
# hardcore ADJ
# accidental ADJ
# racism NOUN
# , PUNCT
# but CCONJ
# it PRON
# fits VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# cried VERB
# my PRON
# eyes NOUN
# out ADP
# , PUNCT
# longing VERB
# for ADP
# the DET
# days NOUN
# just ADV
# a DET
# mere ADJ
# 10 NUM
# 1 NUM
# / SYM
# 2 NUM
# months NOUN
# or CCONJ
# so ADV
# ago ADV
# when SCONJ
# i PRON
# called VERB
# this DET
# ` PUNCT
# ` PUNCT
# home NOUN
# ' PUNCT
# ' PUNCT
# and CCONJ
# knew VERB
# that SCONJ
# i PRON
# had VERB
# a DET
# safe ADJ
# haven NOUN
# to PART
# rest VERB
# my PRON
# head NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# friend NOUN
# and CCONJ
# i PRON
# were AUX
# walking VERB
# home ADV
# from ADP
# school NOUN
# as ADP
# per ADP
# usual ADJ
# as SCONJ
# we PRON
# lived VERB
# close ADV
# to ADP
# each DET
# other ADJ
# and CCONJ
# this PRON
# was AUX
# the DET
# normal ADJ
# routine NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# a DET
# fraying VERB
# rope NOUN
# stretches VERB
# down ADP
# from ADP
# the DET
# rafters NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# had VERB
# to PART
# chord VERB
# with ADP
# my PRON
# thumb NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# after ADP
# that DET
# first ADJ
# big ADJ
# experience NOUN
# i PRON
# started VERB
# doing VERB
# some DET
# research NOUN
# because SCONJ
# i PRON
# was AUX
# so ADV
# confused ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# heart NOUN
# was AUX
# beating VERB
# fast ADV
# from ADP
# excitement NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# nose NOUN
# is AUX
# currently ADV
# upset ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# way NOUN
# i PRON
# was AUX
# positioned VERB
# with ADP
# the DET
# air NOUN
# moving VERB
# made VERB
# it PRON
# hard ADJ
# to PART
# not PART
# breath VERB
# through ADP
# my PRON
# mouth NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# & CCONJ
# gt PROPN
# ; PUNCT
# me PRON
# : PUNCT
# " PUNCT
# wait VERB
# , PUNCT
# really ADV
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# has AUX
# sat VERB
# with ADP
# me PRON
# , PUNCT
# back ADV
# in ADP
# the DET
# pit NOUN
# of ADP
# my PRON
# stomach NOUN
# since SCONJ
# sunday PROPN
# night NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# went VERB
# at ADP
# it PRON
# twice ADV
# , PUNCT
# until SCONJ
# the DET
# muscles NOUN
# around ADP
# my PRON
# mouth NOUN
# hurt VERB
# and CCONJ
# my PRON
# innards NOUN
# almost ADV
# came VERB
# out ADP
# together ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# tried VERB
# to PART
# be AUX
# an DET
# easy ADJ
# going VERB
# bride NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ( PUNCT
# you PRON
# see VERB
# , PUNCT
# i PRON
# have VERB
# these PRON
# afi PROPN
# patches NOUN
# that SCONJ
# i PRON
# bought VERB
# in ADP
# 2004 NUM
# and CCONJ
# i PRON
# had VERB
# no PRON
# where SCONJ
# to PART
# put VERB
# them PRON
# ) PUNCT
# yesterday NOUN
# i PRON
# bought VERB
# this DET
# neato NOUN
# bag NOUN
# and CCONJ
# i PRON
# said VERB
# to ADP
# my PRON
# brain NOUN
# ' PUNCT
# ' PUNCT
# i PRON
# can AUX
# put VERB
# my PRON
# patches NOUN
# on ADP
# this DET
# here ADJ
# bag NOUN
# . PUNCT
# ' PUNCT
# ' PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# this PRON
# is AUX
# so ADV
# odd ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# takes VERB
# them PRON
# 6 NUM
# guys NOUN
# , PUNCT
# all DET
# firefighters NOUN
# mind VERB
# , PUNCT
# and CCONJ
# one NUM
# old ADJ
# schoolteacher NOUN
# , PUNCT
# to PART
# lift VERB
# this DET
# oak NOUN
# dresser NOUN
# off ADP
# meridian PROPN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# about ADV
# ten NUM
# years NOUN
# ago ADV
# , PUNCT
# he PRON
# passed VERB
# away ADV
# from ADP
# a DET
# severe ADJ
# brain NOUN
# tumor NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# best ADJ
# part NOUN
# however ADV
# was AUX
# when SCONJ
# she PRON
# jumped VERB
# into ADP
# the DET
# pictures NOUN
# and CCONJ
# pushed VERB
# the DET
# dog NOUN
# into ADP
# my PRON
# hands NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# can AUX
# ' AUX
# t NOUN
# wait VERB
# to PART
# be AUX
# in ADP
# another DET
# wedding NOUN
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# black ADJ
# eyed ADJ
# kids NOUN
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# look VERB
# at ADP
# them PRON
# once ADV
# and CCONJ
# that PRON
# ' PUNCT
# s AUX
# it PRON
# whispered VERB
# my PRON
# wife NOUN
# in ADP
# my PRON
# ears NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# and CCONJ
# my PRON
# brain NOUN
# can AUX
# think VERB
# up ADP
# some DET
# pretty ADV
# horrible ADJ
# ailments NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# legs NOUN
# felt VERB
# sluggish ADJ
# , PUNCT
# my PRON
# calves NOUN
# were AUX
# burning VERB
# , PUNCT
# my PRON
# right ADJ
# foot NOUN
# was AUX
# pinched VERB
# , PUNCT
# and CCONJ
# i PRON
# couldn PROPN
# ' PUNCT
# t NOUN
# settle VERB
# into ADP
# my PRON
# typical ADJ
# breathing NOUN
# pattern NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# can AUX
# ' VERB
# t NOUN
# move VERB
# , PUNCT
# my PRON
# hand NOUN
# is AUX
# stuck ADJ
# , PUNCT
# i PRON
# ' AUX
# m AUX
# making VERB
# weird ADJ
# noises NOUN
# and CCONJ
# my PRON
# mom NOUN
# is AUX
# screaming VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# ) PUNCT
# i PRON
# started VERB
# to PART
# teach VERB
# myself PRON
# japanese ADJ
# , PUNCT
# and CCONJ
# just ADV
# couldn PROPN
# ' PUNCT
# t NOUN
# shake VERB
# the DET
# feeling NOUN
# that SCONJ
# i PRON
# was AUX
# supposed VERB
# to PART
# live VERB
# there ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# this PRON
# was AUX
# fairly ADV
# recently ADV
# . PUNCT
# . PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# her PRON
# nose NOUN
# was AUX
# broken VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# wow INTJ
# , PUNCT
# that PRON
# is AUX
# really ADV
# interesting ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# and CCONJ
# burst VERB
# into ADP
# tears NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# never ADV
# been AUX
# so ADV
# close ADJ
# to ADP
# a DET
# group NOUN
# ass NOUN
# - PUNCT
# wooping VERB
# in ADP
# my PRON
# life NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# heart NOUN
# sank VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# actually ADV
# what PRON
# ' AUX
# s AUX
# going VERB
# on ADP
# in ADP
# my PRON
# head NOUN
# is AUX
# a DET
# lot NOUN
# of ADP
# congestion NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# he PRON
# also ADV
# worse ADJ
# black ADJ
# gloves NOUN
# and CCONJ
# a DET
# black ADJ
# ski NOUN
# mask NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# police NOUN
# were AUX
# called VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# overflowed VERB
# and CCONJ
# brown ADJ
# shitty PROPN
# diarrhea NOUN
# water NOUN
# came AUX
# flooding VERB
# under ADP
# the DET
# stall NOUN
# wall NOUN
# into ADP
# my PRON
# wife NOUN
# ' PUNCT
# s NOUN
# stall NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# rip VERB
# my PRON
# heart NOUN
# out ADP
# and CCONJ
# stomp ADV
# that PRON
# sucker VERB
# flat ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# was AUX
# not PART
# happy ADJ
# with ADP
# the DET
# waking VERB
# up ADP
# , PUNCT
# but CCONJ
# was AUX
# awake ADJ
# because SCONJ
# my PRON
# hands NOUN
# were AUX
# on ADP
# fire NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# one NOUN
# screamed VERB
# out ADP
# that SCONJ
# it PRON
# was AUX
# screwed VERB
# up ADP
# , PUNCT
# to PART
# which PRON
# another PRON
# replied VERB
# " PUNCT
# to ADP
# the DET
# max PROPN
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# brought VERB
# by ADP
# to ADP
# reality NOUN
# when SCONJ
# noona PROPN
# hit VERB
# my PRON
# arm NOUN
# lightly ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# remember VERB
# the DET
# sweat NOUN
# burning VERB
# in ADP
# my PRON
# eyes NOUN
# and CCONJ
# trying VERB
# to PART
# control VERB
# my PRON
# breathing NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# untie VERB
# my PRON
# bear NOUN
# bag NOUN
# and CCONJ
# grab VERB
# some DET
# food NOUN
# inside ADP
# it PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# got VERB
# close ADJ
# enough ADV
# to PART
# feel VERB
# some PRON
# of ADP
# the DET
# spray NOUN
# from ADP
# the DET
# falls NOUN
# landing VERB
# on ADP
# my PRON
# lips NOUN
# and CCONJ
# glasses NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# walk VERB
# right ADV
# over ADV
# to ADP
# the DET
# tv NOUN
# , PUNCT
# stand VERB
# face NOUN
# to PART
# face VERB
# with ADP
# it PRON
# , PUNCT
# and CCONJ
# begin VERB
# to PART
# point VERB
# at ADP
# the DET
# little ADJ
# number NOUN
# areas NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# wake VERB
# up ADP
# very ADV
# easily ADV
# to ADP
# sounds VERB
# so ADV
# i PRON
# ' VERB
# m VERB
# not PART
# overly ADV
# concerned ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# and CCONJ
# i PRON
# laughed VERB
# like ADP
# this PRON
# : PUNCT
# garhahagar PROPN
# , PUNCT
# because SCONJ
# my PRON
# mouth NOUN
# was AUX
# full ADJ
# of ADP
# cotton NOUN
# and CCONJ
# shit NOUN
# to PART
# bite VERB
# down ADP
# on ADP
# and CCONJ
# sharp ADJ
# objects NOUN
# and CCONJ
# drills NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# its PRON
# very ADV
# dark ADJ
# and CCONJ
# foggy ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# was AUX
# late ADJ
# and CCONJ
# they PRON
# were AUX
# asleep ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# a DET
# deep ADJ
# thud NOUN
# sound NOUN
# in ADP
# the DET
# room NOUN
# and CCONJ
# a DET
# grin NOUN
# spread VERB
# across ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# dad NOUN
# is AUX
# a DET
# minister NOUN
# and CCONJ
# part NOUN
# of ADP
# his PRON
# duties NOUN
# is AUX
# visiting VERB
# the DET
# sick ADJ
# and CCONJ
# dying VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# we PRON
# moved VERB
# to ADP
# a DET
# labor NOUN
# and CCONJ
# delivery NOUN
# room NOUN
# and CCONJ
# i PRON
# labored VERB
# mostly ADV
# on ADP
# my PRON
# hands NOUN
# and CCONJ
# knees NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# ' PUNCT
# s VERB
# so ADV
# stressful ADJ
# but CCONJ
# i PRON
# ' PUNCT
# d VERB
# never ADV
# wanna NOUN
# be AUX
# with ADP
# anyone PRON
# else ADV
# and CCONJ
# i PRON
# ' VERB
# d INTJ
# marry VERB
# her PRON
# this DET
# minute NOUN
# if SCONJ
# the DET
# financial ADJ
# made VERB
# sense NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# i PRON
# don PROPN
# ' PUNCT
# t NOUN
# have VERB
# time NOUN
# to PART
# arrest VERB
# drunk ADJ
# drivers NOUN
# because SCONJ
# of ADP
# all DET
# the DET
# murders NOUN
# , PUNCT
# rapes NOUN
# , PUNCT
# and CCONJ
# robberies NOUN
# we PRON
# have VERB
# to PART
# deal VERB
# with ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# looked VERB
# at ADP
# my PRON
# wrist NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# arch NOUN
# stop VERB
# your PRON
# progression NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# this DET
# ' PUNCT
# star NOUN
# ' PUNCT
# , PUNCT
# starts VERB
# to PART
# move VERB
# across ADP
# the DET
# sky NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] PUNCT
# and CCONJ
# my PRON
# feet NOUN
# hurt VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# so ADV
# i PRON
# cried VERB
# my PRON
# eyes NOUN
# out ADP
# and CCONJ
# did VERB
# the DET
# drawing NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# they PRON
# were AUX
# coal NOUN
# black NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# but CCONJ
# not PART
# very ADV
# happy ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# well INTJ
# she PRON
# ' AUX
# s AUX
# not PART
# gon VERB
# na PART
# last VERB
# the DET
# whole ADJ
# song NOUN
# like ADP
# that PRON
# , PUNCT
# so CCONJ
# since SCONJ
# i PRON
# ' VERB
# m VERB
# behind ADP
# her PRON
# and CCONJ
# the DET
# audience NOUN
# can AUX
# ' AUX
# t NOUN
# see VERB
# below ADP
# my PRON
# torso NOUN
# pretty ADV
# much ADV
# , PUNCT
# i PRON
# use VERB
# my PRON
# hand NOUN
# to PART
# push VERB
# down ADP
# on ADP
# the DET
# lid NOUN
# and CCONJ
# support VERB
# her PRON
# weight NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# she PRON
# sat VERB
# at ADP
# her PRON
# papa NOUN
# ' PUNCT
# s PART
# recliner NOUN
# sofa NOUN
# only ADV
# to PART
# move VERB
# next ADV
# to ADP
# me PRON
# and CCONJ
# start VERB
# clinging VERB
# to ADP
# my PRON
# arms NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# yes INTJ
# , PUNCT
# the DET
# oklahoma PROPN
# city PROPN
# bombing NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# they PRON
# were AUX
# dancing VERB
# to ADP
# bolero NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# still ADV
# had VERB
# sex NOUN
# with ADP
# ...
# - PUNCT
# i PRON
# was AUX
# , PUNCT
# upon SCONJ
# my PRON
# soul NOUN
# - PUNCT
# - PUNCT
# once SCONJ
# my PRON
# cheeks NOUN
# was AUX
# roses NOUN
# , PUNCT
# my PRON
# eyes NOUN
# was AUX
# black ADJ
# as ADP
# coal NOUN
# ; PUNCT
# and CCONJ
# i PRON
# can AUX
# ' AUX
# t NOUN
# remember VERB
# , PUNCT
# in ADP
# them PRON
# days NOUN
# , PUNCT
# of ADP
# hearin NOUN
# ' PART
# people NOUN
# say VERB
# , PUNCT
# for ADP
# any DET
# kind NOUN
# of ADP
# a DET
# reason NOUN
# , PUNCT
# that SCONJ
# i PRON
# was AUX
# in ADP
# their PRON
# way NOUN
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# eating VERB
# at ADP
# an DET
# ethiopian ADJ
# cafe NOUN
# the DET
# other ADJ
# day NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# anesthesiologist NOUN
# put VERB
# an DET
# oxygen NOUN
# mask NOUN
# over ADP
# my PRON
# face NOUN
# , PUNCT
# told VERB
# me PRON
# it PRON
# wasn NOUN
# ' PART
# t NOUN
# the DET
# good ADJ
# stuff NOUN
# yet ADV
# , PUNCT
# then ADV
# i PRON
# woke VERB
# up ADP
# to ADP
# the DET
# room NOUN
# flipping VERB
# around ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# had VERB
# something PRON
# similar ADJ
# , PUNCT
# less ADV
# extreme ADJ
# happen VERB
# to ADP
# me PRON
# once ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# come VERB
# downstairs ADV
# and CCONJ
# see VERB
# grandma NOUN
# at ADP
# the DET
# dining NOUN
# room NOUN
# table NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# we PRON
# had AUX
# recently ADV
# transferred VERB
# g NOUN
# to ADP
# his PRON
# own ADJ
# bedroom NOUN
# and CCONJ
# crib NOUN
# from ADP
# a DET
# cradle NOUN
# that PRON
# was AUX
# still ADV
# in ADP
# the DET
# master NOUN
# bedroom NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# leg NOUN
# so ADV
# tired ADJ
# 4 NUM
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# less ADV
# sad ADJ
# about ADP
# missing VERB
# my PRON
# birthday NOUN
# though ADV
# and CCONJ
# more ADV
# sad ADJ
# about ADP
# missing VERB
# her PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# linzi NOUN
# and CCONJ
# i PRON
# of ADP
# course NOUN
# tried VERB
# them PRON
# , PUNCT
# a DET
# decision NOUN
# that PRON
# i PRON
# immediately ADV
# questioned VERB
# after ADP
# putting VERB
# it PRON
# in ADP
# my PRON
# mouth NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# throw VERB
# my PRON
# hands NOUN
# up ADP
# in ADP
# the DET
# air NOUN
# sometimes ADV
# sayin PROPN
# ' PUNCT
# ay NOUN
# - PUNCT
# oh INTJ
# , PUNCT
# got VERB
# ta PART
# let VERB
# go VERB
# i PRON
# wan X
# na PART
# celebrate VERB
# and CCONJ
# live VERB
# my PRON
# life NOUN
# sayin PROPN
# ' PUNCT
# ay NOUN
# - PUNCT
# oh INTJ
# , PUNCT
# baby NOUN
# let VERB
# ' PUNCT
# s PRON
# go VERB
# ' PUNCT
# cause SCONJ
# we PRON
# gon VERB
# ' PUNCT
# rock NOUN
# this DET
# club NOUN
# we PRON
# gon VERB
# ' PUNCT
# go VERB
# all DET
# night NOUN
# we PRON
# gon VERB
# ' PUNCT
# light VERB
# it PRON
# up ADP
# like ADP
# it PRON
# ' PUNCT
# s NOUN
# dynamite NOUN
# ' PUNCT
# cause SCONJ
# i PRON
# told VERB
# you PRON
# once ADV
# now ADV
# i PRON
# told VERB
# you PRON
# twice ADV
# we PRON
# gon VERB
# ' PUNCT
# light VERB
# it PRON
# up ADP
# like ADP
# it PRON
# ' PUNCT
# s VERB
# dynamite ADJ
# god PROPN
# , PUNCT
# i PRON
# wish VERB
# i PRON
# could AUX
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# a DET
# clip NOUN
# board NOUN
# was AUX
# forced VERB
# into ADP
# my PRON
# hands NOUN
# as SCONJ
# i PRON
# stood AUX
# lost VERB
# in ADP
# a DET
# dark ADJ
# abyss NOUN
# unaware ADJ
# of ADP
# the DET
# reality NOUN
# going VERB
# on ADP
# around ADP
# me PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# so ADV
# my PRON
# leg NOUN
# is AUX
# shaking VERB
# at ADP
# a DET
# million NUM
# miles NOUN
# an DET
# hour NOUN
# and CCONJ
# i PRON
# turn VERB
# into ADP
# the DET
# target NOUN
# parking NOUN
# lot NOUN
# as SCONJ
# she PRON
# sort ADV
# of ADV
# continues VERB
# to PART
# follow VERB
# me PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# back NOUN
# started AUX
# aching VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# feel VERB
# bad ADJ
# for ADP
# my PRON
# employees NOUN
# too ADV
# - PUNCT
# they PRON
# ' PUNCT
# re ADP
# all ADV
# sad ADJ
# and CCONJ
# call VERB
# me PRON
# almost ADV
# everyday ADV
# , PUNCT
# and CCONJ
# it PRON
# really ADV
# breaks VERB
# my PRON
# heart NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# stopped VERB
# for ADP
# water NOUN
# at ADP
# the DET
# rest NOUN
# stops NOUN
# and CCONJ
# got AUX
# doused VERB
# with ADP
# a DET
# hose NOUN
# , PUNCT
# which PRON
# was AUX
# very ADV
# pleasant ADJ
# except SCONJ
# my PRON
# shoes NOUN
# got AUX
# drenched VERB
# so ADV
# i PRON
# was AUX
# running VERB
# with ADP
# heavy ADJ
# sponges NOUN
# on ADP
# my PRON
# feet NOUN
# for ADP
# the DET
# last ADJ
# two NUM
# miles NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# think VERB
# my PRON
# calf NOUN
# super ADV
# muscular ADJ
# le INTJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# there PRON
# was VERB
# nothing PRON
# else ADV
# of ADP
# mine NOUN
# in ADP
# her PRON
# belongings NOUN
# , PUNCT
# and CCONJ
# i PRON
# stood VERB
# up ADP
# and CCONJ
# dusted VERB
# my PRON
# hands NOUN
# off ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# sat VERB
# there ADV
# and CCONJ
# closed VERB
# my PRON
# eyes NOUN
# as ADP
# the DET
# water NOUN
# ( PUNCT
# oyu NOUN
# for ADP
# hot ADJ
# water NOUN
# , PUNCT
# people NOUN
# , PUNCT
# not PART
# mizu ADJ
# ) PUNCT
# swirled VERB
# around ADP
# me PRON
# like ADP
# a DET
# mini ADJ
# massage NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# they PRON
# said VERB
# they PRON
# don PROPN
# ' PART
# t NOUN
# remember VERB
# any DET
# man NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# in ADP
# the DET
# past NOUN
# , PUNCT
# whenever SCONJ
# i PRON
# ' AUX
# ve AUX
# gained VERB
# weight NOUN
# , PUNCT
# it PRON
# went VERB
# straight ADV
# to ADP
# my PRON
# hips NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# tried VERB
# to PART
# keep VERB
# my PRON
# hands NOUN
# washed VERB
# and CCONJ
# be AUX
# very ADV
# careful ADJ
# around ADP
# the DET
# kids NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# brother NOUN
# noticed VERB
# my PRON
# face NOUN
# was AUX
# really ADV
# red ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# remember VERB
# being AUX
# scared ADJ
# shitless NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# know VERB
# in ADP
# my PRON
# brain NOUN
# i PRON
# need VERB
# to PART
# get VERB
# it PRON
# back ADV
# , PUNCT
# but CCONJ
# i PRON
# have VERB
# to PART
# find VERB
# a DET
# way NOUN
# to PART
# make VERB
# it PRON
# real ADJ
# again ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# i PRON
# radioed VERB
# to PART
# infinity VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# was AUX
# up ADP
# - PUNCT
# hill NOUN
# to PART
# get VERB
# to ADP
# school NOUN
# . PUNCT
# . PUNCT
# . PUNCT
# . PUNCT
# . PUNCT
# and CCONJ
# up ADP
# - PUNCT
# hill NOUN
# again ADV
# walking VERB
# back ADV
# home ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# fingers NOUN
# are AUX
# crossed VERB
# ! PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# levi NOUN
# and CCONJ
# i PRON
# arrived VERB
# in ADP
# an DET
# eye NOUN
# - PUNCT
# capturing VERB
# city NOUN
# that PRON
# really ADV
# blew VERB
# me PRON
# off ADP
# my PRON
# feet NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# or CCONJ
# the DET
# darkness NOUN
# in ADP
# my PRON
# eyes NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# started VERB
# out ADP
# slow ADV
# , PUNCT
# like ADP
# we PRON
# ' VERB
# d NOUN
# fight NOUN
# once ADV
# a DET
# month NOUN
# over ADP
# stupid ADJ
# little ADJ
# things NOUN
# and CCONJ
# sometimes ADV
# big ADJ
# things NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# ' AUX
# ve AUX
# got VERB
# it PRON
# all PRON
# planned VERB
# up ADP
# in ADP
# my PRON
# head NOUN
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# that PRON
# took VERB
# about ADV
# a PRON
# week NOUN
# and CCONJ
# a DET
# half NOUN
# , PUNCT
# then ADV
# i PRON
# had VERB
# surgery NOUN
# to PART
# put VERB
# eight NUM
# plates NOUN
# in ADP
# my PRON
# face NOUN
# to PART
# rebuild VERB
# it PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# she PRON
# sat VERB
# me PRON
# in ADP
# the DET
# chair NOUN
# and CCONJ
# spent VERB
# a DET
# total NOUN
# of ADP
# 30 NUM
# seconds NOUN
# looking VERB
# in ADP
# my PRON
# mouth NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# as SCONJ
# the DET
# priest NOUN
# asks VERB
# if SCONJ
# there PRON
# is VERB
# any DET
# objections NOUN
# , PUNCT
# a DET
# huge ADJ
# booming ADJ
# thunder NOUN
# rolls VERB
# out ADP
# , PUNCT
# sounding VERB
# like ADP
# a DET
# cannon NOUN
# in ADP
# the DET
# church NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# was AUX
# trying VERB
# to PART
# concentrate VERB
# on ADP
# not PART
# falling VERB
# , PUNCT
# but CCONJ
# i PRON
# totally ADV
# slipped VERB
# and CCONJ
# almost ADV
# fell VERB
# on ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# screamed VERB
# the DET
# chest NOUN
# pain NOUN
# was AUX
# so ADV
# bad ADJ
# i PRON
# clutched VERB
# my PRON
# chest NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# as SCONJ
# i PRON
# walked VERB
# down ADP
# the DET
# steps NOUN
# , PUNCT
# i PRON
# thought VERB
# i PRON
# felt VERB
# eyes NOUN
# on ADP
# my PRON
# back NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# well INTJ
# , PUNCT
# i PRON
# was AUX
# being AUX
# nice ADJ
# and CCONJ
# throwing VERB
# our PRON
# trash NOUN
# away ADV
# at ADP
# sonic PROPN
# . PUNCT
# . PUNCT
# . PUNCT
# he PRON
# started VERB
# to PART
# back VERB
# up ADP
# , PUNCT
# so ADV
# i PRON
# slammed VERB
# my PRON
# hands NOUN
# on ADP
# the DET
# front NOUN
# of ADP
# the DET
# car NOUN
# , PUNCT
# so ADV
# he PRON
# started VERB
# to PART
# pull VERB
# forward ADV
# . PUNCT
# . PUNCT
# . PUNCT
# i PRON
# laughed VERB
# , PUNCT
# finding VERB
# it PRON
# funny ADJ
# , PUNCT
# and CCONJ
# then ADV
# i PRON
# slowly ADV
# realized VERB
# that SCONJ
# the DET
# car NOUN
# was AUX
# against ADP
# my PRON
# shins NOUN
# and CCONJ
# my PRON
# feet NOUN
# were AUX
# under ADP
# the DET
# bumper NOUN
# of ADP
# the DET
# car NOUN
# . PUNCT
# . PUNCT
# . PUNCT
# . PUNCT
# . PUNCT
# . PUNCT
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# so ADV
# i PRON
# decide VERB
# to PART
# just ADV
# lean VERB
# against ADP
# the DET
# railing NOUN
# and CCONJ
# smoke VERB
# my PRON
# cigarette NOUN
# with ADP
# a DET
# stupid ADJ
# look NOUN
# on ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# we PRON
# don PROPN
# ' PUNCT
# t NOUN
# have VERB
# anything PRON
# that PRON
# they PRON
# want VERB
# , PUNCT
# so ADV
# they PRON
# told VERB
# me PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# but CCONJ
# , PUNCT
# to ADP
# his PRON
# dismay NOUN
# , PUNCT
# the DET
# toilet NOUN
# won VERB
# ' PART
# t NOUN
# flush NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# you PRON
# guys NOUN
# were AUX
# asking VERB
# me PRON
# , PUNCT
# why SCONJ
# am AUX
# i PRON
# so ADV
# quiet ADJ
# and CCONJ
# you PRON
# guys NOUN
# are AUX
# not PART
# use ADJ
# to ADP
# me PRON
# shutting VERB
# my PRON
# mouth NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# grief NOUN
# does VERB
# funny ADJ
# things NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# poor ADJ
# little ADJ
# guy NOUN
# was AUX
# completely ADV
# * PUNCT
# covered VERB
# * PUNCT
# in ADP
# fleas NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# at ADP
# this DET
# point NOUN
# my PRON
# legs NOUN
# were AUX
# starting VERB
# to PART
# ache NOUN
# and CCONJ
# i PRON
# was AUX
# hoping VERB
# for ADP
# something PRON
# to PART
# lift VERB
# my PRON
# spirits NOUN
# and CCONJ
# there PRON
# were VERB
# mom NOUN
# and CCONJ
# andy PROPN
# cheering VERB
# me PRON
# on ADP
# around ADP
# mile NOUN
# 8 NUM
# . PUNCT
# 5 NUM
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# even ADV
# with ADP
# an DET
# armed ADJ
# officer NOUN
# of ADP
# the DET
# law NOUN
# at ADP
# my PRON
# back NOUN
# , PUNCT
# it PRON
# was AUX
# a DET
# bit NOUN
# unnerving ADJ
# to PART
# open VERB
# the DET
# front ADJ
# door NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# first ADJ
# college NOUN
# room NOUN
# mate NOUN
# ever ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# can AUX
# go VERB
# pee PROPN
# here ADV
# but CCONJ
# that PRON
# ' PUNCT
# s VERB
# all PRON
# and CCONJ
# then ADV
# no DET
# water NOUN
# to PART
# wash VERB
# my PRON
# hands NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# * PUNCT
# * PUNCT
# the DET
# rational ADJ
# part NOUN
# of ADP
# my PRON
# brain NOUN
# : PUNCT
# * PUNCT
# * PUNCT
# i PRON
# will AUX
# not PART
# click VERB
# this PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# when SCONJ
# mike PROPN
# walked VERB
# in ADP
# the DET
# door NOUN
# , PUNCT
# my PRON
# heart NOUN
# skipped VERB
# a DET
# beat NOUN
# and CCONJ
# i PRON
# had VERB
# the DET
# biggest ADJ
# smile NOUN
# on ADP
# my PRON
# face NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# if SCONJ
# the DET
# noise NOUN
# hurt VERB
# * PUNCT
# your PRON
# * PUNCT
# ears NOUN
# then ADV
# it PRON
# must AUX
# have AUX
# really ADV
# hurt VERB
# theirs PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# parallel ADJ
# universe NOUN
# answering VERB
# machine NOUN
# : PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# have VERB
# so ADV
# much ADJ
# stuff NOUN
# in ADP
# my PRON
# head NOUN
# right ADV
# now ADV
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# it PRON
# was AUX
# funny ADJ
# because SCONJ
# i PRON
# thought VERB
# i PRON
# broke VERB
# my PRON
# arm NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# knees NOUN
# are AUX
# banged VERB
# to PART
# shit VERB
# tho NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# she PRON
# just ADV
# saw VERB
# red ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# would AUX
# then ADV
# freeze VERB
# with ADP
# fear NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# my PRON
# knees NOUN
# remained VERB
# together ADV
# throughout ADV
# , PUNCT
# but CCONJ
# my PRON
# clitty ADJ
# kept VERB
# becoming VERB
# excited ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# just ADV
# before SCONJ
# my PRON
# garmin NOUN
# watch NOUN
# went VERB
# ` PUNCT
# ` PUNCT
# beep VERB
# beep PROPN
# ' PUNCT
# ' PUNCT
# i PRON
# could AUX
# officially ADV
# feel VERB
# my PRON
# fingers NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# they PRON
# arrest VERB
# him PRON
# on ADP
# gun NOUN
# charges NOUN
# , PUNCT
# rape NOUN
# , PUNCT
# possession NOUN
# of ADP
# child NOUN
# pornography NOUN
# , PUNCT
# drinking VERB
# underage NOUN
# ( PUNCT
# bal PROPN
# was AUX
# 0 NUM
# . PUNCT
# 34 NUM
# ) PUNCT
# as ADV
# well ADV
# as ADP
# exploitation NOUN
# of ADP
# a DET
# minor NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# totally ADV
# forgot VERB
# to PART
# add VERB
# : PUNCT
# i PRON
# ' VERB
# m VERB
# straight ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# kimchi PROPN
# tasted VERB
# bland NOUN
# on ADP
# my PRON
# tongue NOUN
# - PUNCT
# perhaps ADV
# i PRON
# added VERB
# too ADV
# much ADJ
# water NOUN
# , PUNCT
# which PRON
# i PRON
# staunchly ADV
# agreed VERB
# with ADP
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# exact ADJ
# same ADJ
# guy NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# about ADV
# 15 NUM
# minutes NOUN
# later ADV
# i PRON
# got VERB
# that DET
# feeling NOUN
# in ADP
# my PRON
# stomach NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# in ADP
# retrospect NOUN
# this DET
# implied VERB
# extreme ADJ
# circumstances NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# well INTJ
# , PUNCT
# i PRON
# started VERB
# to PART
# realize VERB
# that SCONJ
# it PRON
# wasn NOUN
# ' PART
# t NOUN
# going VERB
# to PART
# work VERB
# out ADP
# in ADP
# the DET
# long ADJ
# run NOUN
# ( PUNCT
# surprise NOUN
# , PUNCT
# surprise NOUN
# ) PUNCT
# and CCONJ
# so ADV
# i PRON
# broke VERB
# it PRON
# off ADP
# with ADP
# her PRON
# as ADV
# gently ADV
# as ADP
# possible ADJ
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# listen VERB
# as SCONJ
# she PRON
# tells VERB
# you PRON
# she PRON
# doesn VERB
# ' PUNCT
# t NOUN
# want VERB
# to PART
# date VERB
# you PRON
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# they PRON
# are AUX
# so ADV
# pillowy ADJ
# that SCONJ
# when SCONJ
# i PRON
# get VERB
# in ADP
# the DET
# car NOUN
# , PUNCT
# while SCONJ
# she PRON
# cheers VERB
# at ADP
# me PRON
# , PUNCT
# she PRON
# actually ADV
# lifts VERB
# her PRON
# fat ADJ
# pillow NOUN
# , PUNCT
# let VERB
# me PRON
# sit VERB
# next ADV
# to ADP
# her PRON
# , PUNCT
# and CCONJ
# then ADV
# drops VERB
# her PRON
# huge ADJ
# mountain NOUN
# of ADP
# fat NOUN
# on ADP
# my PRON
# thigh NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# half NOUN
# of ADP
# my PRON
# heart NOUN
# , PUNCT
# pulled VERB
# out ADP
# of ADP
# my PRON
# chest NOUN
# and CCONJ
# sat VERB
# in ADP
# front NOUN
# of ADP
# me PRON
# , PUNCT
# stretched VERB
# out ADP
# to ADP
# a DET
# thin ADJ
# quiet ADJ
# man NOUN
# with ADP
# a DET
# buzz NOUN
# cut NOUN
# and CCONJ
# old ADJ
# black ADJ
# sweater NOUN
# that PRON
# smells VERB
# like ADP
# clean ADJ
# dirt NOUN
# and CCONJ
# cheap ADJ
# beer NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# " PUNCT
# yeah INTJ
# , PUNCT
# but CCONJ
# did AUX
# you PRON
# just ADV
# find VERB
# that PRON
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# i PRON
# did VERB
# as ADV
# little ADJ
# as ADP
# possible ADJ
# with ADP
# my PRON
# right ADJ
# hand NOUN
# on ADP
# sunday PROPN
# and CCONJ
# took VERB
# a DET
# long ADJ
# nap NOUN
# with ADP
# my PRON
# hand NOUN
# in ADP
# an DET
# elevated ADJ
# and CCONJ
# comfortable ADJ
# position NOUN
# sunday PROPN
# afternoon NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# okay INTJ
# that PRON
# sucks VERB
# , PUNCT
# right ADJ
# ? PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# the DET
# spark NOUN
# leaped VERB
# through ADP
# his PRON
# body NOUN
# into ADP
# mine PRON
# , PUNCT
# and CCONJ
# then ADV
# out ADV
# my PRON
# hand NOUN
# to ADP
# the DET
# cart NOUN
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# [ X
# CLS X
# ] X
# he PRON
# had VERB
# 4 NUM
# inches NOUN
# and CCONJ
# 40 NUM
# pounds NOUN
# on ADP
# me PRON
# and CCONJ
# i PRON
# still ADV
# won VERB
# . PUNCT
# [ X
# SEP PROPN
# ] PUNCT
# (116, 4072)
# (2768, 4072)

# %%
# X_train_t = torch.Tensor(X_train)
# y_train_t = torch.Tensor(y_train)

# X_val_t = torch.Tensor(X_val)
# y_val_t = torch.Tensor(y_val)

# %%
print(f'Shape of X: {X_train.shape}')
print(f'Shape of y: {y_train.shape}')
print(f'Number of positives per emotion class:')
_ = [print(f' - {e}: {v} ({round(100*v/len(y_train))}%)') for e,v in zip(emotions, y_train.sum(axis=0))]
# Out:
# Shape of X: (2768, 4072)
# Shape of y: (2768, 5)
# Number of positives per emotion class:
#  - Joy: 674 (24%)
#  - Sadness: 878 (32%)
#  - Surprise: 839 (30%)
#  - Fear: 1611 (58%)
#  - Anger: 333 (12%)

# %%
# Use POS Tagging

# Function to extract POS tags
def extract_pos_tags(texts):
    tagged_texts = []
    for text in texts:
        doc = nlp(text)
        tagged_texts.append(" ".join([token.pos_ for token in doc]))
    return tagged_texts

# print(train["text"])

# Extract POS tags
train_pos_tags = extract_pos_tags(train["text"])
print(train_pos_tags)

from sklearn.preprocessing import OneHotEncoder
import numpy as np
# Instantiate the encoder
encoder = OneHotEncoder(sparse_output=False, handle_unknown="ignore")

# try:
#     # Split each string into a list of tags and encode
#     pos_encoded = encoder.fit_transform([tags.split() for tags in pos_tags])
#     print("Encoding successful. Shape:", pos_encoded.shape)
# except Exception as e:
#     print("Error during encoding:", e)


# empty_or_irregular = [tags for tags in pos_tags if not tags or len(tags.split()) == 0]
# print("Empty or irregular entries:", empty_or_irregular[:10])

# Find the maximum number of tags in any sentence
train_max_length = max(len(tags.split()) for tags in train_pos_tags)
print(train_max_length)


# Pad the shorter lists with 'PAD' to ensure uniform length
train_padded_pos_tags = [tags.split() + ['PAD'] * (train_max_length - len(tags.split())) for tags in train_pos_tags]
print(train_padded_pos_tags)
unique_tags = set(tag for sentence in train_padded_pos_tags for tag in sentence)
print(unique_tags)
# Now encode the padded lists
try:
    train_pos_encoded = encoder.fit_transform(train_padded_pos_tags)
    print("Encoding successful. Shape:", train_pos_encoded.shape)
except Exception as e:
    print("Error during encoding after padding:", e)


# Fit and transform the POS tags
# pos_encoded = encoder.fit_transform([tags.split() for tags in pos_tags])
# pos_encoded_dense = pos_encoded.toarray()  # Convert sparse matrix to dense

# assert X_train.shape[0] == pos_encoded.shape[0], "Mismatch in number of rows between X and POS encoded features."

combined_features = np.concatenate((X_train, train_pos_encoded), axis=1)

# POS Tagging for Validation set 

val_pos_tags = extract_pos_tags(val["text"])
print(val_pos_tags)
# train_tags = set(tag for tags in train_pos_tags for tag in tags.split())
# val_tags = set(tag for tags in val_pos_tags for tag in tags.split())

# print("Tags in training set but not in validation:", train_tags - val_tags)
# print("Tags in validation set but not in training:", val_tags - train_tags)

# try:
#     # Split each string into a list of tags and encode
#     pos_encoded = encoder.fit_transform([tags.split() for tags in pos_tags])
#     print("Encoding successful. Shape:", pos_encoded.shape)
# except Exception as e:
#     print("Error during encoding:", e)


# empty_or_irregular = [tags for tags in pos_tags if not tags or len(tags.split()) == 0]
# print("Empty or irregular entries:", empty_or_irregular[:10])

# Find the maximum number of tags in any sentence
# val_max_length = max(len(tags.split()) for tags in val_pos_tags)
# print(val_max_length)

# Pad the shorter lists with 'PAD' to ensure uniform length
val_padded_pos_tags = [tags.split() + ['PAD'] * (train_max_length - len(tags.split())) for tags in val_pos_tags]
print(val_padded_pos_tags)
# Now encode the padded lists
# try:
val_pos_encoded = encoder.transform(val_padded_pos_tags) ## Same encoder that has already been trained
print("Encoding successful. Shape:", val_pos_encoded.shape)
# except Exception as e:
#     print("Error during encoding:", e)


# Fit and transform the POS tags
# pos_encoded = encoder.fit_transform([tags.split() for tags in pos_tags])
# pos_encoded_dense = pos_encoded.toarray()  # Convert sparse matrix to dense

# assert X_train.shape[0] == pos_encoded.shape[0], "Mismatch in number of rows between X and POS encoded features."

validation_combined_features = np.concatenate((X_val, val_pos_encoded), axis=1)

print(combined_features.shape)
print(validation_combined_features.shape)

# Now pos_encoded contains a one-hot encoded numpy array of POS tags
# Assuming 'other_features' is your main feature matrix derived from your text (e.g., TF-IDF)
# Make sure both arrays have the same number of rows
# combined_features = np.concatenate((X_train, pos_encoded), axis=1)
# Out:
# ['CCONJ PART ADV ADJ PUNCT', 'INTJ PRON AUX PART VERB PART VERB DET ADJ NOUN ADP PRON PUNCT CCONJ SCONJ PRON AUX ADP PRON CCONJ DET NOUN AUX PART VERB ADP PRON NOUN ADV ADV PUNCT PRON VERB PRON NOUN PART VERB ADP ADP DET NOUN CCONJ VERB PRON NOUN PUNCT', 'PRON VERB ADP PRON PROPN PART NOUN NOUN ADV PART VERB ADV ADP PRON CCONJ VERB VERB ADP PRON NOUN PUNCT', 'INTJ PUNCT DET PROPN NOUN NOUN PUNCT', 'PRON AUX VERB ADP PROPN PUNCT', 'ADV VERB NOUN ADP PRON PUNCT ADV PUNCT', 'CCONJ PRON AUX VERB PUNCT PRON NOUN VERB SCONJ PRON AUX ADJ PART VERB ADP ADP PRON NOUN PUNCT PRON VERB DET VERB NOUN CCONJ NOUN PART VERB PRON NOUN PUNCT ADV ADP DET ADJ NOUN PUNCT ADV VERB PRON ADV SYM NOUN NUM NOUN PROPN PART PROPN PROPN PUNCT NUM NOUN ADV ADJ NOUN PUNCT ADJ NOUN ADP NOUN ADP NOUN PUNCT', 'PRON VERB DET NOUN ADP PROPN ADV ADP VERB NOUN ADP DET NOUN SCONJ ADP DET ADJ NOUN DET NOUN VERB PUNCT', 'ADV PRON NOUN VERB ADP DET NOUN PUNCT CCONJ DET NOUN AUX ADP DET ADJ NOUN PUNCT', 'PRON VERB ADP DET NOUN CCONJ PRON NOUN VERB VERB VERB PUNCT PUNCT ADP DET ADJ NOUN NOUN PUNCT ADP NOUN VERB ADP NOUN PUNCT', 'PRON VERB PRON NOUN PUNCT VERB DET NOUN PUNCT VERB NOUN ADP NOUN NOUN ADP NOUN CCONJ NOUN PUNCT', 'DET NOUN AUX ADJ CCONJ ADV VERB CCONJ PRON VERB ADP DET NUM PUNCT NOUN NOUN VERB DET NOUN ADP DET NOUN PUNCT SCONJ VERB ADP VERB ADP PRON NOUN SCONJ VERB ADP DET NOUN ADP DET NOUN VERB PUNCT ADV PRON AUX PRON VERB PUNCT', 'DET NOUN ADP DET NOUN VERB ADP DET ADJ ADP PRON NOUN PUNCT', 'PRON VERB NOUN ADJ PUNCT', 'PRON VERB DET ADJ ADJ ADP PRON NOUN PART VERB PRON AUX ADJ PUNCT', 'ADV NUM NOUN ADV PRON VERB PRON VERB DET NOUN ADP PRON NOUN PUNCT', 'PRON ADV AUX PART VERB PRON PUNCT', 'ADV ADJ ADP ADJ AUX ADP DET NOUN ADP DET NOUN PUNCT', 'NUM NOUN ADJ PRON AUX ADJ ADP NOUN PUNCT', 'DET NOUN VERB ADJ NOUN NOUN CCONJ VERB DET ADJ NOUN ADP NOUN ADP PRON NOUN CCONJ DET NOUN AUX PROPN PUNCT', 'ADV PRON VERB PART VERB CCONJ VERB ADP PART VERB ADP DET NOUN PUNCT CCONJ PRON AUX PART VERB PUNCT', 'PUNCT DET NOUN VERB PRON PART VERB DET ADJ NOUN CCONJ VERB ADV PUNCT', 'DET VERB NUM NOUN PUNCT PRON AUX ADP DET ADJ NOUN ADP NOUN CCONJ VERB ADV ADJ NOUN ADP NOUN ADP PRON NOUN PUNCT', 'PRON VERB NOUN CCONJ VERB PUNCT SPACE PUNCT PROPN PUNCT', 'PART DET ADV ADJ NOUN PUNCT CCONJ DET ADV ADJ NOUN ADP PRON NOUN AUX SCONJ VERB PUNCT', 'SCONJ DET NOUN VERB PRON VERB ADP ADP PRON NOUN CCONJ VERB PRON AUX ADJ CCONJ PRON VERB PRON AUX ADJ ADV PRON ADV VERB NOUN ADP PRON NOUN PUNCT', 'PRON VERB PRON VERB PUNCT', 'PRON VERB PRON NOUN ADP ADV DET DET NOUN PUNCT', 'ADJ PART VERB PUNCT PRON VERB PRON ADP PUNCT', 'PRON VERB PRON NOUN SCONJ PRON VERB ADP PRON NOUN PUNCT DET ADJ NOUN PART PART VERB ADV ADP PROPN PUNCT', 'ADV VERB PRON ADV PUNCT', 'ADV AUX PART VERB PRON NOUN ADP DET NOUN SCONJ DET NOUN NUM NOUN ADV VERB NOUN PUNCT', 'PROPN VERB ADV PUNCT VERB ADP DET NOUN ADP NOUN CCONJ VERB PUNCT', 'PRON NOUN ADV VERB PUNCT', 'ADV PRON AUX PART SCONJ NOUN VERB SCONJ PRON VERB ADP DET NOUN SCONJ DET NOUN AUX PART VERB PART VERB PRON NOUN ADP NOUN ADV PRON VERB NOUN NOUN ADV PUNCT', 'PRON AUX DET NOUN ADP DET NOUN DET NOUN PRON AUX VERB PUNCT VERB SCONJ ADP DET ADJ NOUN ADP PUNCT PRON VERB DET NOUN SCONJ PRON VERB ADP NOUN PUNCT PUNCT PRON NOUN AUX PART VERB ADV PUNCT', 'PRON AUX VERB PART VERB ADJ SCONJ PRON AUX ADV ADP DET NOUN ADP NUM NOUN CCONJ DET NOUN ADP NOUN PRON VERB AUX VERB PART VERB PRON CCONJ VERB ADP DET NOUN ADP PRON NOUN PUNCT ADP DET NUM NOUN PUNCT', 'PUNCT PUNCT ADJ NOUN NOUN NOUN PUNCT INTJ PUNCT PRON VERB DET NOUN ADP PRON VERB NOUN VERB ADV PUNCT CCONJ PRON ADV AUX PART VERB ADJ VERB PRON ADP PRON PUNCT', 'PRON AUX ADV ADV VERB ADP ADJ NOUN PUNCT', 'PRON NOUN VERB DET NOUN PUNCT ADV ADV ADP DET NOUN PUNCT', 'PRON VERB CCONJ PRON AUX PART VERB CCONJ VERB DET ADJ NOUN ADP PRON NOUN PUNCT', 'VERB PRON NOUN ADP NUM NOUN PUNCT PRON VERB CCONJ VERB PUNCT PUNCT PROPN PUNCT PUNCT', 'PROPN PUNCT VERB PRON NOUN', 'ADJ NOUN ADJ PUNCT PRON ADV VERB ADJ NOUN ADP ADV ADJ NOUN ...
# 91
# [['CCONJ', 'PART', 'ADV', 'ADJ', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['INTJ', 'PRON', 'AUX', 'PART', 'VERB', 'PART', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'PRON', 'PUNCT', 'CCONJ', 'SCONJ', 'PRON', 'AUX', 'ADP', 'PRON', 'CCONJ', 'DET', 'NOUN', 'AUX', 'PART', 'VERB', 'ADP', 'PRON', 'NOUN', 'ADV', 'ADV', 'PUNCT', 'PRON', 'VERB', 'PRON', 'NOUN', 'PART', 'VERB', 'ADP', 'ADP', 'DET', 'NOUN', 'CCONJ', 'VERB', 'PRON', 'NOUN', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['PRON', 'VERB', 'ADP', 'PRON', 'PROPN', 'PART', 'NOUN', 'NOUN', 'ADV', 'PART', 'VERB', 'ADV', 'ADP', 'PRON', 'CCONJ', 'VERB', 'VERB', 'ADP', 'PRON', 'NOUN', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['INTJ', 'PUNCT', 'DET', 'PROPN', 'NOUN', 'NOUN', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['PRON', 'AUX', 'VERB', 'ADP', 'PROPN', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['ADV', 'VERB', 'NOUN', 'ADP', 'PRON', 'PUNCT', 'ADV', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['CCONJ', 'PRON', 'AUX', 'VERB', 'PUNCT', 'PRON', 'NOUN', 'VERB', 'SCONJ', 'PRON ...
# {'PUNCT', 'AUX', 'SYM', 'SCONJ', 'PART', 'DET', 'ADP', 'NOUN', 'ADJ', 'X', 'PAD', 'ADV', 'INTJ', 'SPACE', 'PRON', 'CCONJ', 'PROPN', 'VERB', 'NUM'}
# Encoding successful. Shape: (2768, 1175)
# ['PRON NOUN VERB ADJ PUNCT PUNCT INTJ PUNCT INTJ PUNCT INTJ PUNCT PRON PUNCT', 'PRON AUX ADV VERB ADP PRON NOUN PART ADJ NOUN ADP DET NOUN ADP PRON NOUN PUNCT', 'CCONJ ADP VERB PRON NOUN ADP DET ADJ NOUN VERB PROPN NOUN PUNCT NOUN PROPN PROPN PUNCT PROPN PROPN PROPN PROPN PROPN PROPN PROPN PROPN PUNCT', 'ADV VERB ADP PRON NOUN PRON VERB ADP DET NOUN SCONJ ADV AUX ADV VERB VERB ADP PRON PUNCT', 'PRON VERB DET NOUN ADP VERB ADV CCONJ VERB PRON ADP PRON ADJ NOUN ADP PRON NOUN ADJ PUNCT', 'PRON VERB PART SCONJ PUNCT PRON VERB PRON NOUN PUNCT', 'PRON AUX ADV ADJ PUNCT', 'PRON AUX VERB ADP DET NOUN NOUN PUNCT CCONJ PRON AUX AUX AUX VERB ADP NUM NOUN PUNCT DET NOUN VERB SCONJ PRON NOUN AUX VERB PRON AUX NOUN PUNCT', 'PUNCT PUNCT ADP DET NOUN PRON AUX VERB ADV CCONJ VERB PRON NOUN ADP DET NOUN PUNCT PRON VERB ADP ADP PRON NOUN ADV PUNCT', 'PRON VERB SCONJ PRON AUX ADV ADP PRON NOUN PUNCT ADP PROPN PUNCT', 'PRON AUX VERB ADP ADP PRON NOUN SCONJ PRON PROPN CCONJ NOUN CCONJ NOUN VERB PART VERB PROPN PROPN CCONJ VERB PROPN NOUN NOUN PUNCT', 'PRON NOUN AUX VERB PUNCT', 'PUNCT CCONJ PROPN ADV VERB PUNCT', 'PRON ADV VERB PRON PUNCT', 'PRON AUX ADV ADV PUNCT', 'ADV ADV DET ADJ NOUN ADP DET NOUN PUNCT', 'NOUN PUNCT ADJ PUNCT ADJ ADJ ADJ NOUN AUX PART AUX VERB ADV ADV PUNCT', 'PRON VERB ADV ADP PRON NOUN PUNCT VERB SCONJ DET ADJ NOUN ADP DET NOUN PRON AUX ADJ ADV PART VERB ADP CCONJ VERB DET NOUN ADP ADJ VERB PRON NOUN ADV ADP PRON NOUN PUNCT', 'PRON NOUN AUX VERB ADV CCONJ VERB PRON ADV ADP DET NOUN SCONJ DET ADJ NOUN CCONJ PRON PRON AUX VERB ADP NOUN ADP DET NOUN ADP DET NOUN VERB ADP PRON NOUN PUNCT', 'PROPN PUNCT DET NOUN ADP NOUN AUX AUX AUX VERB ADV ADP PRON NOUN SCONJ PRON VERB PART VERB DET ADJ NOUN CCONJ VERB PRON ADJ NUM ADP DET NOUN NOUN SCONJ PRON AUX NOUN NOUN NOUN VERB PUNCT', 'SCONJ NOUN VERB PRON PUNCT DET NOUN PUNCT AUX PUNCT PROPN ADV VERB SCONJ PUNCT PRON AUX VERB ADV PUNCT PUNCT CCONJ PRON VERB SCONJ SCONJ PRON VERB ADP PUNCT DET NOUN PUNCT PUNCT ADV PUNCT PRON VERB ADJ PUNCT PUNCT', 'DET NOUN AUX VERB PART VERB ADV ADP PRON NOUN PUNCT CCONJ PRON ADV AUX PART VERB PRON NOUN CCONJ ADV VERB DET NOUN PUNCT', 'ADJ NOUN PUNCT NUM ADP DET NOUN PUNCT AUX DET PROPN PROPN PUNCT', 'ADV PRON VERB PART PUNCT INTJ PUNCT VERB NOUN ADP SYM NOUN PRON PUNCT', 'ADJ PUNCT ADV ADJ NOUN PRON AUX ADV VERB PUNCT', 'NOUN ADP NOUN PUNCT ADJ PUNCT', 'PRON VERB ADV DET NOUN ADP PRON ADP PRON NOUN ADP DET NOUN ADP DET NOUN PRON PRON VERB PART VERB PART VERB PUNCT', 'PUNCT SPACE PRON AUX INTJ PUNCT ADJ PUNCT', 'PROPN PROPN VERB DET ADV ADJ NOUN ADP PRON NOUN PUNCT', 'INTJ PUNCT ADV PRON NOUN NOUN PART NOUN AUX ADV ADP ADP PRON NOUN PUNCT DET ADJ PRON VERB PRON NOUN DET NOUN ADP NUM NOUN PUNCT DET ADJ ADJ NOUN PRON VERB AUX PRON NOUN ADP DET PROPN ADP PRON NOUN VERB ADV ADP PRON PUNCT', 'ADV PUNCT PRON VERB ADP CCONJ VERB ADV ADV CCONJ VERB PART VERB PRON NOUN CCONJ VERB PRON NOUN PUNCT PRON AUX VERB ADJ SCONJ VERB ADP DET NOUN ADP DET NOUN VERB ADP NUM NOUN PUNCT', 'CCONJ PROPN SYM NUM PUNCT NOUN PUNCT PRON PRON AUX AUX VERB DET NOUN ADP ADP DET ADJ NOUN NOUN PROPN VERB DET NOUN ADV ADP VERB ADV ADP NOUN ADP NOUN CCONJ ADV ADV ADP PRON PRON AUX VERB DET ADJ NOUN VERB DET PROPN ADP DET NOUN CCONJ ADV VERB PRON ADP PRON NOUN PUNCT', 'VERB ADP DET NOUN ADP ADJ ADJ NOUN PUNCT', 'PRON AUX VERB ADP ADV PUNCT AUX ADJ ADP PRON ADJ ADJ NOUN PUNCT', 'DET NOUN AUX VERB ADJ PART VERB PUNCT CCONJ PRON AUX PART ADP ADV PUNCT ADV PRON VERB PRON NOUN ADP DET NOUN ADP DET NOUN PART VERB PRON ADJ ADP PRON PUNCT', 'NOUN CCONJ PRON VERB ADV CCONJ ADV ADP DET NOUN ADP ADV ADV NUM CCONJ NUM NOUN SCONJ PRON VERB PRON NOUN AUX VERB PUNCT', 'PRON VERB DET NOUN NOUN ADP DET NOUN PUNCT ADV ADP PRON NOUN AUX ADJ PUNCT', 'PRON AUX PART VERB ADV PUNCT PRON NOUN AUX AUX VERB ADP ADP NUM NOUN PUNCT PRON AUX VERB ADP NOUN PUNCT AUX PART VERB PUNCT PRON AUX ADV PUNCT PRON AUX PUNCT PRON VERB SCONJ PRON AUX VERB PUNCT', 'ADV VERB ADP ADP DET NOUN VERB DET NOUN ADP PRON NOUN PUNCT PRON CC ...
# [['PRON', 'NOUN', 'VERB', 'ADJ', 'PUNCT', 'PUNCT', 'INTJ', 'PUNCT', 'INTJ', 'PUNCT', 'INTJ', 'PUNCT', 'PRON', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['PRON', 'AUX', 'ADV', 'VERB', 'ADP', 'PRON', 'NOUN', 'PART', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'NOUN', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['CCONJ', 'ADP', 'VERB', 'PRON', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'PROPN', 'NOUN', 'PUNCT', 'NOUN', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['ADV', 'VERB', 'ADP', 'PRON', 'NOUN', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'SCONJ', 'ADV', 'AUX', 'ADV', 'VERB', 'VERB', 'ADP', 'PRON', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'ADV', 'CCONJ', 'VERB', 'PRON', 'ADP', 'PRON', 'ADJ', 'NOUN', 'ADP', 'PRON', 'NOUN', 'ADJ', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['PRON', 'VERB', 'PART', 'SCONJ', 'PUNCT', 'PRON', 'VERB', 'PRON', 'NOUN', 'PUNCT', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD'], ['PRON', 'AUX', 'ADV', 'ADJ', 'PUNCT', 'PAD', 'PAD', 'PAD' ...
# Encoding successful. Shape: (116, 1175)
# (2768, 5247)
# (116, 5247)

# %%
model = nn.Sequential(
          nn.Linear(combined_features.shape[1], 100),
          nn.BatchNorm1d(100),  # Batch normalization for 100 features
          nn.ReLU(),
          nn.Dropout(0.3),
          nn.Linear(100, y_train.shape[1])
        )

# %%
# model = nn.Sequential(
#     nn.Linear(combined_features.shape[1], 100),
#     nn.BatchNorm1d(100),  # Batch normalization for 100 features
#     nn.ReLU(),
#     nn.Dropout(0.3),
#     nn.Linear(100, 50),   # Additional intermediate layer
#     nn.BatchNorm1d(50),   # Batch normalization for 50 features
#     nn.ReLU(),
#     nn.Linear(50, y_train.shape[1]),
#     nn.BatchNorm1d(y_train.shape[1]),  # Optionally add BatchNorm here if suitable
#     nn.ReLU()  # Final activation if needed (depends on the output requirement)
# )

# %%
from torch.utils.data import DataLoader, TensorDataset
import torch
from tqdm import tqdm 

# Add early stopping" TBC 
# best_loss = float('inf')
# patience = 20  # Number of epochs to wait for improvement before stopping
# patience_counter = 0  # Tracks how many epochs have passed without improvement


# Convert to torch tensors
features_tensor = torch.tensor(combined_features, dtype=torch.float32)
labels_tensor = torch.tensor(y_train, dtype=torch.float32)

# Create dataset and data loader
dataset = TensorDataset(features_tensor, labels_tensor)
data_loader = DataLoader(dataset, batch_size=10, shuffle=True)

# Define loss function and optimizer
criterion = nn.BCEWithLogitsLoss() # Use BCE with Logit Loss because it is multi-hot
optimizer = optim.SGD(model.parameters(), lr=1e-2, weight_decay=1e-2) ## Lower the learning rate from 1e-1 to 1e-2 to try to decrease the fluctuation in loss

# Training loop
for epoch in tqdm(range(1000), desc="Training Loop:"):
    for features, labels in data_loader:
        optimizer.zero_grad()
        outputs = model(features)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
    if epoch % 100 == 0:
        print(f'Epoch {epoch}: Loss: {round(loss.item(),3)}')
    if epoch == 1000:
        print(f'Epoch {epoch}: Loss: {round(loss.item(),3)}')

    # print(f'Epoch {epoch+1}, Loss: {loss.item()}')

"""Previous results:

Training Loop::   0%|          | 1/1000 [00:00<08:14,  2.02it/s]
Epoch 0: Loss: 0.432
Training Loop::  10%|█         | 101/1000 [01:54<19:53,  1.33s/it]
Epoch 100: Loss: 0.194
Training Loop::  20%|██        | 201/1000 [04:53<42:45,  3.21s/it]
Epoch 200: Loss: 0.166
Training Loop::  30%|███       | 301/1000 [06:41<07:41,  1.51it/s]
Epoch 300: Loss: 0.155
Training Loop::  40%|████      | 401/1000 [08:21<08:29,  1.18it/s]
Epoch 400: Loss: 0.196
Training Loop::  50%|█████     | 501/1000 [09:52<07:15,  1.15it/s]
Epoch 500: Loss: 0.153
Training Loop::  60%|██████    | 601/1000 [11:55<07:03,  1.06s/it]
Epoch 600: Loss: 0.245
Training Loop::  70%|███████   | 701/1000 [13:46<11:18,  2.27s/it]
Epoch 700: Loss: 0.161
Training Loop::  80%|████████  | 801/1000 [15:22<03:38,  1.10s/it]
Epoch 800: Loss: 0.215
Training Loop::  90%|█████████ | 901/1000 [16:29<01:01,  1.62it/s]
Epoch 900: Loss: 0.152
Training Loop:: 100%|██████████| 1000/1000 [19:10<00:00,  1.15s/it]

"""
# Out:
# Training Loop::   0%|          | 1/1000 [00:04<1:08:12,  4.10s/it]
# Epoch 0: Loss: 0.582
# Training Loop::  10%|█         | 101/1000 [03:38<24:03,  1.61s/it]
# Epoch 100: Loss: 0.166
# Training Loop::  20%|██        | 201/1000 [06:45<31:29,  2.36s/it]
# Epoch 200: Loss: 0.28
# Training Loop::  30%|███       | 301/1000 [09:04<16:03,  1.38s/it]
# Epoch 300: Loss: 0.155
# Training Loop::  40%|████      | 401/1000 [13:16<27:07,  2.72s/it]
# Epoch 400: Loss: 0.194
# Training Loop::  50%|█████     | 501/1000 [18:03<22:46,  2.74s/it]
# Epoch 500: Loss: 0.231
# Training Loop::  60%|██████    | 601/1000 [22:44<17:32,  2.64s/it]
# Epoch 600: Loss: 0.268
# Training Loop::  70%|███████   | 701/1000 [27:16<13:44,  2.76s/it]
# Epoch 700: Loss: 0.231
# Training Loop::  80%|████████  | 801/1000 [30:34<05:15,  1.58s/it]
# Epoch 800: Loss: 0.132
# Training Loop::  90%|█████████ | 901/1000 [33:38<03:18,  2.01s/it]
# Epoch 900: Loss: 0.233
# Training Loop:: 100%|██████████| 1000/1000 [36:35<00:00,  2.20s/it]
# 'Previous results:\n\nTraining Loop::   0%|          | 1/1000 [00:00<08:14,  2.02it/s]\nEpoch 0: Loss: 0.432\nTraining Loop::  10%|█         | 101/1000 [01:54<19:53,  1.33s/it]\nEpoch 100: Loss: 0.194\nTraining Loop::  20%|██        | 201/1000 [04:53<42:45,  3.21s/it]\nEpoch 200: Loss: 0.166\nTraining Loop::  30%|███       | 301/1000 [06:41<07:41,  1.51it/s]\nEpoch 300: Loss: 0.155\nTraining Loop::  40%|████      | 401/1000 [08:21<08:29,  1.18it/s]\nEpoch 400: Loss: 0.196\nTraining Loop::  50%|█████     | 501/1000 [09:52<07:15,  1.15it/s]\nEpoch 500: Loss: 0.153\nTraining Loop::  60%|██████    | 601/1000 [11:55<07:03,  1.06s/it]\nEpoch 600: Loss: 0.245\nTraining Loop::  70%|███████   | 701/1000 [13:46<11:18,  2.27s/it]\nEpoch 700: Loss: 0.161\nTraining Loop::  80%|████████  | 801/1000 [15:22<03:38,  1.10s/it]\nEpoch 800: Loss: 0.215\nTraining Loop::  90%|█████████ | 901/1000 [16:29<01:01,  1.62it/s]\nEpoch 900: Loss: 0.152\nTraining Loop:: 100%|██████████| 1000/1000 [19:10<00:00,  1.15s/it]\n\n'

# %%
# criterion = nn.BCEWithLogitsLoss()
# optimizer = optim.SGD(model.parameters(), lr=1e-1, weight_decay=1e-2)

# %%
# Train for a set number of epochs
# for epoch in range(1000):
#     optimizer.zero_grad()
#     output = model(X_train_t)
    # loss = criterion(output, y_train_t)
    # loss.backward()
    # optimizer.step()    
    # if epoch % 100 == 0:
    #     print(f'Epoch {epoch}: Loss: {round(loss.item(),3)}')

# %%
def get_predictions(X_val, model, threshold=0.5):
    sig = nn.Sigmoid() 
    yhat = sig(model(X_val)).detach().numpy()
    y_pred = yhat > threshold
    
    return y_pred

# %%
# Check the shape of the input features for validation and model’s expected input
validation_features_tensor = torch.tensor(validation_combined_features, dtype=torch.float32)

print("Validation data shape:", validation_features_tensor.shape)
print("Expected input shape:", model[0].in_features)
# Out:
# Validation data shape: torch.Size([116, 5247])
# Expected input shape: 5247

# %%
y_pred = get_predictions(validation_features_tensor, model, 0.45)
# print(y_pred)

# Create a DataFrame to save to CSV
val_data_with_pred = pd.DataFrame(y_pred, columns=['Anger', 'Fear', 'Joy', 'Sadness', 'Surprise'])  # Adjust column names as per your features
# val_data_with_pred['True_Label'] = y_test
# val_data_with_pred['Predictions'] = dummy_predictions

val_data_with_pred = val_data_with_pred.astype(int)

val_data_with_pred['id'] = val['id']

val_data_with_pred = val_data_with_pred[['id', 'Anger', 'Fear', 'Joy', 'Sadness', 'Surprise']]

# Save to CSV
current_time = datetime.datetime.now()
formatted_time = current_time.strftime('%Y-%m-%d_%H_%M_%S')

val_data_with_pred.to_csv(f'../results/pred_eng_a_{formatted_time}.csv', index=False)

print(val_data_with_pred)
# Out:
#                         id  Anger  Fear  Joy  Sadness  Surprise
# 0    eng_dev_track_a_00001      0     1    0        0         0
# 1    eng_dev_track_a_00002      0     0    0        1         0
# 2    eng_dev_track_a_00003      1     0    1        0         0
# 3    eng_dev_track_a_00004      1     0    0        0         0
# 4    eng_dev_track_a_00005      0     0    0        1         0
# ..                     ...    ...   ...  ...      ...       ...
# 111  eng_dev_track_a_00112      0     0    1        1         0
# 112  eng_dev_track_a_00113      0     1    1        1         0
# 113  eng_dev_track_a_00114      0     0    0        1         0
# 114  eng_dev_track_a_00115      0     0    0        0         0
# 115  eng_dev_track_a_00116      0     0    0        0         0
#
# [116 rows x 6 columns]

# %%
# def evaluate(y_val, y_pred):
#     for average in ['micro', 'macro']:
#         recall = recall_score(y_val, y_pred, average=average, zero_division=0)
#         precision = precision_score(y_val, y_pred, average=average, zero_division=0)
#         f1 = f1_score(y_val, y_pred, average=average, zero_division=0)
    
#         print(f'{average.upper()} recall: {round(recall, 4)}, precision: {round(precision, 4)}, f1: {round(f1, 4)}')

# %%
# evaluate(y_val, y_pred) EVALS WON'T WORK HERE

# %%
# def evaluate_per_class(y_val, y_pred):
#     for i, emotion in enumerate(emotions):
#         print(f'*** {emotion} ***')
    
#         recall = recall_score(y_val[:,i], y_pred[:,i], zero_division=0)
#         precision = precision_score(y_val[:,i], y_pred[:,i], zero_division=0)
#         f1 = f1_score(y_val[:,i], y_pred[:,i], zero_division=0)
        
#         print(f'recall: {round(recall, 4)}, precision: {round(precision, 4)}, f1: {round(f1, 4)}\n')

# %%
# evaluate_per_class(y_val, y_pred) EVALS WON'T WORK HERE

# %%
# weights = y_train.sum(axis=0)/y_train.sum()
# weights = max(weights)/weights

# %%
# # # Define model 
# # model = nn.Sequential(
# #           nn.Linear(X_train.shape[1], 100),
# #           nn.ReLU(),
# #           nn.Dropout(0.3),
# #           nn.Linear(100, y_train.shape[1])
# #         )

# # Define training parameters
# # criterion = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor(weights)) # <-- weights assigned to optimiser
# # optimizer = optim.SGD(model.parameters(), lr=1e-1, weight_decay=1e-2)

# criterion = nn.BCEWithLogitsLoss()
# optimizer = optim.SGD(model.parameters(), lr=1e-1, weight_decay=1e-2)

# # # Train for a number of epochs
# # for epoch in range(1000):
# #     optimizer.zero_grad()
# #     output = model(X_train_t)
# #     loss = criterion(output, y_train_t)
# #     loss.backward()
# #     optimizer.step()
# #     if epoch % 100 == 0:
# #         print(f'Epoch {epoch}: Loss: {round(loss.item(),3)}')

# # # Get predictions
# # y_pred = get_predictions(X_val_t, model, 0.45)

# # # Create a DataFrame to save to CSV
# # val_data_with_pred = pd.DataFrame(y_pred, columns=['Anger', 'Fear', 'Joy', 'Sadness', 'Surprise'])  # Adjust column names as per your features
# # # val_data_with_pred['True_Label'] = y_test
# # # val_data_with_pred['Predictions'] = dummy_predictions

# # val_data_with_pred = val_data_with_pred.astype(int)

# # val_data_with_pred['id'] = val['id']

# # val_data_with_pred = val_data_with_pred[['id', 'Anger', 'Fear', 'Joy', 'Sadness', 'Surprise']]

# # Save to CSV
# current_time = datetime.datetime.now()
# formatted_time = current_time.strftime('%Y-%m-%d_%H_%M_%S')

# val_data_with_pred.to_csv(f'../results/pred_eng_a_{formatted_time}.csv', index=False)

# # print(val_data_with_pred)

# # # Evaluate: EVALS WON'T WORK HERE 
# # # print('\n\nEVALUATION\n')
# # # evaluate(y_val, y_pred)

# # # print('\nPER CLASS BREAKDOWN\n')
# # # evaluate_per_class(y_val, y_pred)

# %%
# val_data_with_pred
